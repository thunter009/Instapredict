# %% [markdown]
# First, we want to load packages and create an empty data frame to be filled. Additionally, define a starter key to collect more keys

# %%
import requests
import json
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import time 
import datetime
final = pd.DataFrame(columns = ['caption','comments','filters','hashtags','image','photo_id','likes','time','user', 'scrape_time', 'key', 'tag']) 
#chance this key will have to be changed over time - atm it's just to start collecting other keys
key = 'AQDt5LYE7lbm7Rb2P-ox-rkpSdXXT19HsvYz4Ncf_k2qcjJ3S2crfI9m-jipFD0SOtWBTAIEKkU1AozNIhN52-wfgMbUTr1biNafa9RGWnQpF6izIF8GIiNf1Dvdl_IbnR4'
counter =45000

# %% [markdown]
# Only run the code below if you're looking to get more keys. The number of keys you get will depend on the range

# %%
#collect keys
start = time.time()
result = []  
for i in range(0,500):
    d = {}
    response = requests.post("http://www.instagim.com/ajax/",
        data='get_photos=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%' + key + '%count%3D15%26access_token%3D&next_url=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D%7Bnext_key%7D%26count%3D15%26access_token%3D',
        headers={
            "Accept": "application/json, text/javascript, */*; q=0.01",
            "Accept-Encoding": "gzip, deflate",
            "Accept-Language": "en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4",
            "Connection": "keep-alive",
            "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
            "Origin": "http://www.instagim.com",
            "Referer": "http://www.instagim.com/tag/nature",
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
            "X-Requested-With": "XMLHttpRequest"
        },
        cookies={
            "_ga": "GA1.2.821769385.1489495570",
            "_gat": "1"
        },
    )
    data = json.loads(response.text)
    d['key'] = data['key'].encode('utf-8')
    d['post_time'] = str(time.strftime("%c"))
    d['tag'] = 'nature'
    result.append(d)
    time.sleep(3)
    
print 'Time elapsed: ', time.time() - start
# Out:
# Time elapsed:  2133.24560618

# %% [markdown]
# Simply writing the keys to a csv file while the photos "mature" like fine wine.

# %%
keys_df = pd.DataFrame(result)
print keys_df
keys_df.to_csv('keys'+ str(time.strftime("%c") + '.csv'))
# Out:
#                                                    key  \
# 0    AQBtc9Y2n2HTYKNkDwqVagfKGRWsmz8e9_jcWVXFHYwWPd...
# 1    AQCFyFV9t7DoY9Xa-BS7njnQEU-kpQqMeBFbGcN9AYw_by...
# 2    AQDtBKT4Z6hosMl94jRhj7ZMEoH9-8Ya0KTx468TyCwlGH...
# 3    AQCzK_RPWApXyXzRwfQi7BdOXnsrGhF3C6wfJ7QMKnNSyq...
# 4    AQD3JvTm8p3RkmgaoFa4AgOutnLLoPwHwB4a2dc9crQ7ZU...
# 5    AQDSuRiVutUq56XMfW1p9cS_cmbllQevNfAErY140mbTLz...
# 6    AQAcPecj2Pn1E496RiLra5HEK2jvHImyq4dkumS_F6aHLJ...
# 7    AQAUae5UTPUxIpwrISM6UUvE2QftEeOPj3LRDD5MzXTBmO...
# 8    AQDAIceIHSjByoLd8IPQ4AiCTwa6SCEogYsorT1Cc1A9M_...
# 9    AQDFlXiQivyjAPs4rdFqKexrHJ3yF45t06kb22gQcfijXB...
# 10   AQDN3vwgnD82PfM59YW5WJVMbWpM_-pDMkhAaiil-hT6N4...
# 11   AQAIWsEnBOw9o_cdfZSi1QnxaB7dJSBhiRH7DEHUDjBpGH...
# 12   AQB-p7nXqbsDRgDNm9Qs44BLEUN5g5GihQX8egWppr015h...
# 13   AQDAnWqyIdQoo3TR7QECXUbk_c54fjvZwRyb2O_AZvMHqG...
# 14   AQDUDzaVl2E6SRF4r36GSTO1OOyXTdLAIcWYkiN2SvnUAz...
# 15   AQDwOWxkSZjvVPv1QABGJipAVzLzH9Wm8pvYPUYkrSVebV...
# 16   AQCpQTto6YkkC1AC2zdIKnPqYCYXLPV4Ya6QPqDROGqeXB...
# 17   AQDOHsvJuJp35kQUIm7Hq11QBzIQXC4qkw2al00KfI3hqv...
# 18   AQDfLR9NAQKohcjYmmiFAlOax00FqdU1eQo_xfq5FGfJex...
# 980  Sun Mar 19 12:20:40 2017  awesome
# 981  Sun Mar 19 12:20:42 2017  awesome
# 982  Sun Mar 19 12:20:44 2017  awesome
# 983  Sun Mar 19 12:20:47 2017  awesome
# 984  Sun Mar 19 12:20:48 2017  awesome
# 985  Sun Mar 19 12:20:50 2017  awesome
# 986  Sun Mar 19 12:20:52 2017  awesome
# 987  Sun Mar 19 12:20:54 2017  awesome
# 988  Sun Mar 19 12:20:56 2017  awesome
# 989  Sun Mar 19 12:20:58 2017  awesome
# 990  Sun Mar 19 12:21:00 2017  awesome
# 991  Sun Mar 19 12:21:02 2017  awesome
# 992  Sun Mar 19 12:21:04 2017  awesome
# 993  Sun Mar 19 12:21:05 2017  awesome
# 994  Sun Mar 19 12:21:07 2017  awesome
# 995  Sun Mar 19 12:21:08 2017  awesome
# 996  Sun Mar 19 12:21:10 2017  awesome
# 997  Sun Mar 19 12:21:12 2017  awesome
# 998  Sun Mar 19 12:21:15 2017  awesome
# 999  Sun Mar 19 12:21:18 2017  awesome
#
# [1000 rows x 3 columns]

# %% [markdown]
# Extract the photos from each key

# %%
for index,row in key.iterrows():
    
    response = requests.post("http://www.instagim.com/ajax/",
        data='get_photos=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D' + row['key'] + '%26count%3D15%26access_token%3D&next_url=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D%7Bnext_key%7D%26count%3D15%26access_token%3D',
        headers={
            "Accept": "application/json, text/javascript, */*; q=0.01",
            "Accept-Encoding": "gzip, deflate",
            "Accept-Language": "en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4",
            "Connection": "keep-alive",
            "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
            "Origin": "http://www.instagim.com",
            "Referer": "http://www.instagim.com/tag/nature",
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
            "X-Requested-With": "XMLHttpRequest"
        },
        cookies={
            "_ga": "GA1.2.821769385.1489495570",
            "_gat": "1"
        },
    )

    data = json.loads(response.text)
    text = BeautifulSoup(data['html'], 'html.parser')
    events = text.find_all('div', {'class': "box-photo"})


    result = [] 
    for event in events:
        counter += 1
        d = {} # each event is its own dictionary so initialize it inside the loop
        try: #use try statement so code doesn't break if names are wrong
                 #remember to change this to a counter
                index = counter
                im = [x['src'] for x in event.find('div', {'class': 'photo'}).a][0]
                urllib.urlretrieve(im, str(counter) + ".jpg")
                time_post = event.find('div', {'class': "upload-time"}).get_text()
                user = event.find('div', {'class': "username"}).a.get_text()
                capt = event.find('div', {'class': "photo-description"}).get_text()
                hashtags = event.find('div', {'class': "photo-tags"}).get_text()
                filters = event.find('div', {'class': "filter-text"}).get_text()
                likes = event.find('span', {'class': "icon-thumbs-up-alt"}).get_text()
                comments = event.find('span', {'class': "icon-chat"}).get_text()
        except: 
                index = ""
                im = ""
                time_post = ""
                user = ""
                capt = ""
                hashtags = ""
                filters = ""
                likes = ""
                comments = ""
        finally:  
                d['photo_id'] = index
                d['image'] = im
                d['time'] = time_post
                d['user'] = user             
                d['caption'] = capt
                d['hashtags'] = hashtags
                d['filters'] = filters
                d['likes'] = likes
                d['comments'] = comments
                d['scrape_time'] = str(time.strftime("%c"))
                d['post_time'] = row['post_time']
                d['key'] = row['key']
                d['tag'] = row['tag']
                result.append(d) # each event is own dictionary

    final = final.append(pd.DataFrame(result))

# %% [markdown]
# Double check that your dataframe has been created

# %%
final
# Out:
#                                               caption comments  \
# 0   \r\n                    Oh Konstanz 💕 #willmi...        2
# 1   \r\n                    #rosequartzmountain #s...        0
# 2   \r\n                    Amazing #sunset to a c...        0
# 3   \r\n                    Voyage into the myster...        4
# 4   \r\n                    #chile #instagood #nat...        0
# 5   \r\n                    Cra st désirat 😌 #xc ...        0
# 6   \r\n                    Grumpy fish. #nature #...        0
# 7   \r\n                    #flower #flowers #inst...        0
# 8   \r\n                    Stephanie Inn, Cannon ...        1
# 9   \r\n                    #şiir #şiirisevin #eni...        0
# 10  \r\n                    one of the more beauti...        3
# 11  \r\n                    La hora de jugar de Ti...        4
# 12  \r\n                    Nothing is better than...        1
# 13  \r\n                    Spring is on its way.\...        1
# 14  \r\n                    👌🖐 #pic #foto #fotog...        3
# 0   \r\n                    "Draw a monster. Why i...        0
# 1   \r\n                    Örgülerce💎💎💎#hair #...        0
# 2   \r\n                    #beauty #sunset #sun #...        2
# 3   \r\n                    🌲🐾🐿 #love #nature #...        0
# 4   \r\n                    Amo questo posto !🔝 #...        3
# 5   \r\n                    Suburban Sprawl \nTake...        0
# 6   \r\n                    Groove. Always. And. I...        1
# 7   \r\n                    Oh Konstanz 💕 #willmi...        2
# 8   \r\n                    #rosequartzmountain #s...        0
# 9   \r\n                    Amazing #sunset to a c...        0
# 10  \r\n                    Voyage into the myster...        4
# 11  \r\n                    #chile #instagood #nat...        0
# 12  \r\n                    Cra st désirat 😌 #xc ...        0
# 13  \r\n                    Grumpy fish. #nature #...        0
# 14  \r\n                    #flower #flowers #inst...        0
# ..                                                ...      ...
# 0   \r\n                    #mountain #sudtirol #l...        0
# 1   \r\n                    Today's stage 😍 #hors...        1
# 2   \r\n                    Great day, I'v been wi...        0
# 3   \r\n                    Look deep into nature,...        1
# 4   \r\n                    #garden #quince #delic...        0
# 5   \r\n                    That view! 😍\ncc: @su...        7
# 6   \r\n                    "ocean blue, what have...        0
# 7   \r\n                    Castel Welsperg\n\nW H...        0
# 8   \r\n                    Canal des alpilles..\n...        0
# 9   \r\n                    Relax in the wood🍁\n....        0
# 10  \r\n                    The bees are all over ...        6
# 11  \r\n                    Har sku da det bedste ...        0
# 12  \r\n                    Untitled' new media ©N...        0
# 13  \r\n                    #laotzu #quotes #optim...        0
# 14  \r\n                    #nature #sky #sun #sum...        0
# 0   \r\n                    1/3 pics\n#water #pict...        0
# 1   \r\n                    #Эльбрус Спасибо #fuzb...        0
# 2   \r\n                    Grow.\n#plants #spring...        0
# 3   \r\n                    Nice weather @ the #be...        0
# 4   \r\n                    Dead Sea 🌊 бултыхаешь...        5
# 5   \r\n                    😍\n#instagood#fashion...        2
# 6   \r\n                    #cat #catlover #siusi ...        0
# 7   \r\n                    #walking #marche #natu...        0
# 8   \r\n                    Burning out another gi...        0
# 9   \r\n                    Not my photo 🌤☁️💛 #s...        1
# 10  \r\n                    reggae falls 🇯🇲 @App...        2
# 11  \r\n                    #mountain #sudtirol #l...        0
# 12  \r\n                    Today's stage 😍 #hors...        1
# 13  \r\n                    Great day, I'v been wi...        0
# 14  \r\n                    Look deep into nature,...        1
#
#              filters                                           hashtags  \
# 0      Filter Normal   #happyday #wanderlust #spring #konstanzmylove...
# 1      Filter Normal   #srilanka #lka #travel #exploresrilanka #view...
# 2      Filter Normal   #namphapayaiclimberscamp #outdoors #rockclimb...
# 3      Filter Normal   #quote #yerebatan #igworldclub #light #myster...
# 4      Filter Normal   #treking #friends #chile #sur #travel #todosl...
# 5     Filter Mayfair   #ride #scott #motivation #machine #bike #shim...
# 6      Filter Normal   #naturecenter #animals #instanature #boshnast...
# 7      Filter Normal   #instaflowers #naturelovers #naturelover #flo...
# 8      Filter Normal   #meditation #outdoors #zen #cannonbeach #pray...
# 9   Filter Clarendon   #edebiyat #şiirisevin #bence #literature #me ...
# 10  Filter Clarendon   #grundarfjörður #travel #icelandtravel #agame...
# 11     Filter Normal   #animals #lovekittens #furry #cat #catsofinst...
# 12     Filter Normal   #createexplore #letsgosomewhere #mkexplore #w...
# 13     Filter Normal   #ig_nature #ourfinland #kevät #luontoonfi #sp...
# 14       Filter Lark   #sport #foto #trekking #instachile #nature #p...
# 0   Filter Clarendon   #grass #homework #outdoors #trails #perspecti...
# 1      Filter Normal   #ombre #hairoftheday #kuaför #wedding #düğün ...
# 2   Filter Clarendon   #positive #phonegraphy #zurich #lit #artist #...
# 3      Filter Normal        #love #bosanka #bosna #naturelovers #nature
# 4   Filter Clarendon   #sunday #tuscany #view #italy #nature #landscape
# 5     Filter Slumber   #iphonephotography #sunrise #photography #sun...
# 6      Filter Normal   #rapper #faybanhats #cllsr #420 #cllsrmvstrs ...
# 7      Filter Normal   #konstanzmylove #konstanz #süddeutschland #la...
# 8      Filter Normal   #lka #throwback #srilanka #view #visitsrilank...
# 9      Filter Normal   #namphapayaiclimberscamp #sunset #neverstopex...
# 10     Filter Normal   #street #likesforfollow #istanbul #igworldclu...
# 11     Filter Normal   #instagood #traveler #friends #sur #nature #b...
# 12    Filter Mayfair   #giro #instagood #shimano #levels #fox #bike ...
# 13     Filter Normal   #naturephoto #instaart #boshnastyphotos #cano...
# 14     Filter Normal   #naturelover #instagood #flowerlovers #leaves...
# ..               ...                                                ...
# 0      Filter Normal   #sudtirol #merano #mountain #meranocity #like...
# 1      Filter Normal   #field #farm #horseshoe #jockey #riding #hors...
# 2      Filter Normal   #summer #amazing #neverstopexploring #masca #...
# 3      Filter Normal   #travelling #discoveringthailand #travelaweso...
# 4      Filter Normal   #delicious #springiscoming #quincetree #garde...
# 5      Filter Normal   #summer #stunning #landscape #peak #water #br...
# 6      Filter Normal   #smartphowned #adventures #boating #oceanferr...
# 7        Filter Juno   #purelove #purenature #hrad #landscape #myhom...
# 8       Filter Lo-fi   #portrait #montagne #flowers #garden #fleurs ...
# 9      Filter Normal   #relax #chill #green #reflection #nofilter #p...
# 10     Filter Normal   #happybees #southerngardening #gardening #pol...
# 11     Filter Normal   #skov #gardnersofinstagram #nature #arbejdarb...
# 12     Filter Normal   #digital #artist #painting #toronto #question...
# 13     Filter Normal   #spray #waterfall #motivationclub #visiting #...
# 14     Filter Normal   #summer #green #sky #beach #flowers #clouds #...
# 0      Filter Normal   #water #summer #mountains #liveforthemoment #...
# 1      Filter Normal   #mountains #snowboard #natgeotravel #эльбрус ...
# 2      Filter Normal   #billing #pot #inspire #bloom #earthpot #plan...
# 3      Filter Normal            #bluesky #sea #landscape #beach #nature
# 4        Filter Lark
# 5      Filter Normal   #siberia #model #like #wonderful #face #look ...
# 6        Filter Juno   #landscape_captures #jj #landscape #mountains...
# 7    Filter X-Pro II              #countryside #walking #marche #nature
# 8    Filter Perpetua   #grunge #model #tutu #makeup #mermaid #artist...
# 9      Filter Normal                         #sunset #nature #beautiful
# 10     Filter Normal   #vacation #travelling #fun #happy #view #sea ...
# 11     Filter Normal   #city #meran #like #sudtirol #mountains #moun...
# 12     Filter Normal   #horsesofinstagram #jockey #farm #ilovemyhors...
# 13     Filter Normal   #discover #summer #traveller #amazing #nevers...
# 14     Filter Normal   #travelling #createexploretakeover #bungalow ...
#
#                                                 image  \
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
# ..                                                ...
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
#
#                                                   key likes photo_id  \
# 0                                                 ...   176        1
# 1                                                 ...    64        2
# 2                                                 ...    18        3
# 3                                                 ...   306        4
# 4                                                 ...    52        5
# 5                                                 ...    30        6
# 6                                                 ...    23        7
# 7                                                 ...    33        8
# 8                                                 ...    40        9
# 9                                                 ...    20       10
# 10                                                ...    88       11
# 11                                                ...   185       12
# 12                                                ...    37       13
# 13                                                ...    43       14
# 14                                                ...    32       15
# 0                                                 ...    81       16
# 1                                                 ...    42       17
# 2                                                 ...    33       18
# 3                                                 ...    32       19
# 4                                                 ...    35       20
# 5                                                 ...    43       21
# 6                                                 ...    31       22
# 7                                                 ...   176       23
# 8                                                 ...    64       24
# 9                                                 ...    18       25
# 10                                                ...   306       26
# 11                                                ...    52       27
# 12                                                ...    30       28
# 13                                                ...    23       29
# 14                                                ...    33       30
# ..                                                ...   ...      ...
# 0                                                 ...    30    14971
# 1                                                 ...    20    14972
# 2                                                 ...    98    14973
# 3                                                 ...    62    14974
# 4                                                 ...    20    14975
# 5                                                 ...   511    14976
# 6                                                 ...    45    14977
# 7                                                 ...    98    14978
# 8                                                 ...    38    14979
# 9                                                 ...    28    14980
# 10                                                ...    50    14981
# 11                                                ...    24    14982
# 12                                                ...    28    14983
# 13                                                ...    34    14984
# 14                                                ...    21    14985
# 0                                                 ...     6    14986
# 1                                                 ...    14    14987
# 2                                                 ...   122    14988
# 3                                                 ...    36    14989
# 4                                                 ...   104    14990
# 5                                                 ...    85    14991
# 6                                                 ...    22    14992
# 7                                                 ...    19    14993
# 8                                                 ...    43    14994
# 9                                                 ...    44    14995
# 10                                                ...    47    14996
# 11                                                ...    30    14997
# 12                                                ...    20    14998
# 13                                                ...    98    14999
# 14                                                ...    62    15000
#
#                    post_time               scrape_time      tag       time  \
# 0   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:10 2017  awesome  1 day ago
# 1   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:10 2017  awesome  1 day ago
# 2   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:10 2017  awesome  1 day ago
# 3   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:11 2017  awesome  1 day ago
# 4   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:11 2017  awesome  1 day ago
# 5   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:12 2017  awesome  1 day ago
# 6   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:12 2017  awesome  1 day ago
# 7   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:12 2017  awesome  1 day ago
# 8   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:13 2017  awesome  1 day ago
# 9   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:13 2017  awesome  1 day ago
# 10  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:13 2017  awesome  1 day ago
# 11  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:14 2017  awesome  1 day ago
# 12  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:14 2017  awesome  1 day ago
# 13  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:15 2017  awesome  1 day ago
# 14  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:15 2017  awesome  1 day ago
# 0   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:17 2017  awesome  1 day ago
# 1   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:17 2017  awesome  1 day ago
# 2   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:17 2017  awesome  1 day ago
# 3   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:18 2017  awesome  1 day ago
# 4   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:18 2017  awesome  1 day ago
# 5   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:18 2017  awesome  1 day ago
# 6   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:19 2017  awesome  1 day ago
# 7   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:19 2017  awesome  1 day ago
# 8   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:19 2017  awesome  1 day ago
# 9   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:20 2017  awesome  1 day ago
# 10  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:20 2017  awesome  1 day ago
# 11  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:20 2017  awesome  1 day ago
# 12  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:21 2017  awesome  1 day ago
# 13  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:21 2017  awesome  1 day ago
# 14  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:21 2017  awesome  1 day ago
# ..                       ...                       ...      ...        ...
# 0   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 1   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 2   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 3   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 4   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 5   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 6   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 7   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 8   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 9   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 10  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 11  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 12  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 13  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 14  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 0   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 1   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 2   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 3   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 4   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 5   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 6   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 7   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 8   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 9   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 10  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 11  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 12  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 13  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 14  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
#
#                                user
# 0                        @anker1503
# 1                          @avindi_
# 2                         @jojoyees
# 3                     @keskincigdem
# 4                      @luisfernick
# 5                      @nath_pltn02
# 6                  @boshnastyphotos
# 7                  @likelikelike888
# 8                            @swmag
# 9                    @who_heartless
# 10                       @momo_choo
# 11                @daliycocopersian
# 12                        @foxgoods
# 13                          @juhwes
# 14                    @claucollazou
# 0                        @brennm222
# 1                  @talatkuafor1970
# 2                   @shotdamnxpixxs
# 3                   @lanostravita__
# 4                       @antohoppus
# 5                       @gjroya1225
# 6                     @sarinevasori
# 7                        @anker1503
# 8                          @avindi_
# 9                         @jojoyees
# 10                    @keskincigdem
# 11                     @luisfernick
# 12                     @nath_pltn02
# 13                 @boshnastyphotos
# 14                 @likelikelike888
# ..                              ...
# 0                 @antonio.apuzzo92
# 1                      @foxxsolaire
# 2                         @ilja_sen
# 3                    @sebatiptronic
# 4                    @alida.popescu
# 5                @beyond_landscapes
# 6                @bloody_marionette
# 7                      @whitedog.sk
# 8                            @vie51
# 9                      @eleonore__d
# 10            @thechickpeachickadee
# 11                  @kjeldgaardlene
# 12                   @norhan.ha.art
# 13                      @mariecoach
# 14  @myrose__77_hakareteblokeveceza
# 0             @norwegiannature_pics
# 1                      @zavodchenko
# 2                    @goldenlensguy
# 3               @irisvb_photography
# 4                   @goncharova_msk
# 5                     @nastasya_yuz
# 6                          @kaph_31
# 7                        @cat_ouska
# 8                 @blueeyesdesire90
# 9                     @oliviaszpirt
# 10                        @chefaisi
# 11                @antonio.apuzzo92
# 12                     @foxxsolaire
# 13                        @ilja_sen
# 14                   @sebatiptronic
#
# [15000 rows x 13 columns]

# %% [markdown]
# And finally write that file to a csv!

# %%
final.to_pickle('Mon_Mar20.pickle')

# %% [markdown]
# Pain in the ass but switch to a python 3 environment

# %%
import pickle
new_final = pickle.load( open( "Mon_Mar20.pickle", "rb" ) )

# %%
new_final
# Out:
#                                               caption comments  \
# 0   \r\n                    Oh Konstanz 💕 #willmis...        2
# 1   \r\n                    #rosequartzmountain #s...        0
# 2   \r\n                    Amazing #sunset to a c...        0
# 3   \r\n                    Voyage into the myster...        4
# 4   \r\n                    #chile #instagood #nat...        0
# 5   \r\n                    Cra st désirat 😌 #xc #...        0
# 6   \r\n                    Grumpy fish. #nature #...        0
# 7   \r\n                    #flower #flowers #inst...        0
# 8   \r\n                    Stephanie Inn, Cannon ...        1
# 9   \r\n                    #şiir #şiirisevin #eni...        0
# 10  \r\n                    one of the more beauti...        3
# 11  \r\n                    La hora de jugar de Ti...        4
# 12  \r\n                    Nothing is better than...        1
# 13  \r\n                    Spring is on its way.\...        1
# 14  \r\n                    👌🖐 #pic #foto #fotogra...        3
# 0   \r\n                    "Draw a monster. Why i...        0
# 1   \r\n                    Örgülerce💎💎💎#hair #wed...        0
# 2   \r\n                    #beauty #sunset #sun #...        2
# 3   \r\n                    🌲🐾🐿 #love #nature #nat...        0
# 4   \r\n                    Amo questo posto !🔝 #S...        3
# 5   \r\n                    Suburban Sprawl \nTake...        0
# 6   \r\n                    Groove. Always. And. I...        1
# 7   \r\n                    Oh Konstanz 💕 #willmis...        2
# 8   \r\n                    #rosequartzmountain #s...        0
# 9   \r\n                    Amazing #sunset to a c...        0
# 10  \r\n                    Voyage into the myster...        4
# 11  \r\n                    #chile #instagood #nat...        0
# 12  \r\n                    Cra st désirat 😌 #xc #...        0
# 13  \r\n                    Grumpy fish. #nature #...        0
# 14  \r\n                    #flower #flowers #inst...        0
# ..                                                ...      ...
# 0   \r\n                    #mountain #sudtirol #l...        0
# 1   \r\n                    Today's stage 😍 #horse...        1
# 2   \r\n                    Great day, I'v been wi...        0
# 3   \r\n                    Look deep into nature,...        1
# 4   \r\n                    #garden #quince #delic...        0
# 5   \r\n                    That view! 😍\ncc: @sur...        7
# 6   \r\n                    "ocean blue, what have...        0
# 7   \r\n                    Castel Welsperg\n\nW H...        0
# 8   \r\n                    Canal des alpilles..\n...        0
# 9   \r\n                    Relax in the wood🍁\n.\...        0
# 10  \r\n                    The bees are all over ...        6
# 11  \r\n                    Har sku da det bedste ...        0
# 12  \r\n                    Untitled' new media ©N...        0
# 13  \r\n                    #laotzu #quotes #optim...        0
# 14  \r\n                    #nature #sky #sun #sum...        0
# 0   \r\n                    1/3 pics\n#water #pict...        0
# 1   \r\n                    #Эльбрус Спасибо #fuzb...        0
# 2   \r\n                    Grow.\n#plants #spring...        0
# 3   \r\n                    Nice weather @ the #be...        0
# 4   \r\n                    Dead Sea 🌊 бултыхаешьс...        5
# 5   \r\n                    😍\n#instagood#fashion#...        2
# 6   \r\n                    #cat #catlover #siusi ...        0
# 7   \r\n                    #walking #marche #natu...        0
# 8   \r\n                    Burning out another gi...        0
# 9   \r\n                    Not my photo 🌤☁️💛 #sun...        1
# 10  \r\n                    reggae falls 🇯🇲 @AppLe...        2
# 11  \r\n                    #mountain #sudtirol #l...        0
# 12  \r\n                    Today's stage 😍 #horse...        1
# 13  \r\n                    Great day, I'v been wi...        0
# 14  \r\n                    Look deep into nature,...        1
#
#              filters                                           hashtags  \
# 0      Filter Normal   #happyday #wanderlust #spring #konstanzmylove...
# 1      Filter Normal   #srilanka #lka #travel #exploresrilanka #view...
# 2      Filter Normal   #namphapayaiclimberscamp #outdoors #rockclimb...
# 3      Filter Normal   #quote #yerebatan #igworldclub #light #myster...
# 4      Filter Normal   #treking #friends #chile #sur #travel #todosl...
# 5     Filter Mayfair   #ride #scott #motivation #machine #bike #shim...
# 6      Filter Normal   #naturecenter #animals #instanature #boshnast...
# 7      Filter Normal   #instaflowers #naturelovers #naturelover #flo...
# 8      Filter Normal   #meditation #outdoors #zen #cannonbeach #pray...
# 9   Filter Clarendon   #edebiyat #şiirisevin #bence #literature #me ...
# 10  Filter Clarendon   #grundarfjörður #travel #icelandtravel #agame...
# 11     Filter Normal   #animals #lovekittens #furry #cat #catsofinst...
# 12     Filter Normal   #createexplore #letsgosomewhere #mkexplore #w...
# 13     Filter Normal   #ig_nature #ourfinland #kevät #luontoonfi #sp...
# 14       Filter Lark   #sport #foto #trekking #instachile #nature #p...
# 0   Filter Clarendon   #grass #homework #outdoors #trails #perspecti...
# 1      Filter Normal   #ombre #hairoftheday #kuaför #wedding #düğün ...
# 2   Filter Clarendon   #positive #phonegraphy #zurich #lit #artist #...
# 3      Filter Normal        #love #bosanka #bosna #naturelovers #nature
# 4   Filter Clarendon   #sunday #tuscany #view #italy #nature #landscape
# 5     Filter Slumber   #iphonephotography #sunrise #photography #sun...
# 6      Filter Normal   #rapper #faybanhats #cllsr #420 #cllsrmvstrs ...
# 7      Filter Normal   #konstanzmylove #konstanz #süddeutschland #la...
# 8      Filter Normal   #lka #throwback #srilanka #view #visitsrilank...
# 9      Filter Normal   #namphapayaiclimberscamp #sunset #neverstopex...
# 10     Filter Normal   #street #likesforfollow #istanbul #igworldclu...
# 11     Filter Normal   #instagood #traveler #friends #sur #nature #b...
# 12    Filter Mayfair   #giro #instagood #shimano #levels #fox #bike ...
# 13     Filter Normal   #naturephoto #instaart #boshnastyphotos #cano...
# 14     Filter Normal   #naturelover #instagood #flowerlovers #leaves...
# ..               ...                                                ...
# 0      Filter Normal   #sudtirol #merano #mountain #meranocity #like...
# 1      Filter Normal   #field #farm #horseshoe #jockey #riding #hors...
# 2      Filter Normal   #summer #amazing #neverstopexploring #masca #...
# 3      Filter Normal   #travelling #discoveringthailand #travelaweso...
# 4      Filter Normal   #delicious #springiscoming #quincetree #garde...
# 5      Filter Normal   #summer #stunning #landscape #peak #water #br...
# 6      Filter Normal   #smartphowned #adventures #boating #oceanferr...
# 7        Filter Juno   #purelove #purenature #hrad #landscape #myhom...
# 8       Filter Lo-fi   #portrait #montagne #flowers #garden #fleurs ...
# 9      Filter Normal   #relax #chill #green #reflection #nofilter #p...
# 10     Filter Normal   #happybees #southerngardening #gardening #pol...
# 11     Filter Normal   #skov #gardnersofinstagram #nature #arbejdarb...
# 12     Filter Normal   #digital #artist #painting #toronto #question...
# 13     Filter Normal   #spray #waterfall #motivationclub #visiting #...
# 14     Filter Normal   #summer #green #sky #beach #flowers #clouds #...
# 0      Filter Normal   #water #summer #mountains #liveforthemoment #...
# 1      Filter Normal   #mountains #snowboard #natgeotravel #эльбрус ...
# 2      Filter Normal   #billing #pot #inspire #bloom #earthpot #plan...
# 3      Filter Normal            #bluesky #sea #landscape #beach #nature
# 4        Filter Lark
# 5      Filter Normal   #siberia #model #like #wonderful #face #look ...
# 6        Filter Juno   #landscape_captures #jj #landscape #mountains...
# 7    Filter X-Pro II              #countryside #walking #marche #nature
# 8    Filter Perpetua   #grunge #model #tutu #makeup #mermaid #artist...
# 9      Filter Normal                         #sunset #nature #beautiful
# 10     Filter Normal   #vacation #travelling #fun #happy #view #sea ...
# 11     Filter Normal   #city #meran #like #sudtirol #mountains #moun...
# 12     Filter Normal   #horsesofinstagram #jockey #farm #ilovemyhors...
# 13     Filter Normal   #discover #summer #traveller #amazing #nevers...
# 14     Filter Normal   #travelling #createexploretakeover #bungalow ...
#
#                                                 image  \
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
# ..                                                ...
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
#
#                                                   key likes photo_id  \
# 0                                                 ...   176        1
# 1                                                 ...    64        2
# 2                                                 ...    18        3
# 3                                                 ...   306        4
# 4                                                 ...    52        5
# 5                                                 ...    30        6
# 6                                                 ...    23        7
# 7                                                 ...    33        8
# 8                                                 ...    40        9
# 9                                                 ...    20       10
# 10                                                ...    88       11
# 11                                                ...   185       12
# 12                                                ...    37       13
# 13                                                ...    43       14
# 14                                                ...    32       15
# 0                                                 ...    81       16
# 1                                                 ...    42       17
# 2                                                 ...    33       18
# 3                                                 ...    32       19
# 4                                                 ...    35       20
# 5                                                 ...    43       21
# 6                                                 ...    31       22
# 7                                                 ...   176       23
# 8                                                 ...    64       24
# 9                                                 ...    18       25
# 10                                                ...   306       26
# 11                                                ...    52       27
# 12                                                ...    30       28
# 13                                                ...    23       29
# 14                                                ...    33       30
# ..                                                ...   ...      ...
# 0                                                 ...    30    14971
# 1                                                 ...    20    14972
# 2                                                 ...    98    14973
# 3                                                 ...    62    14974
# 4                                                 ...    20    14975
# 5                                                 ...   511    14976
# 6                                                 ...    45    14977
# 7                                                 ...    98    14978
# 8                                                 ...    38    14979
# 9                                                 ...    28    14980
# 10                                                ...    50    14981
# 11                                                ...    24    14982
# 12                                                ...    28    14983
# 13                                                ...    34    14984
# 14                                                ...    21    14985
# 0                                                 ...     6    14986
# 1                                                 ...    14    14987
# 2                                                 ...   122    14988
# 3                                                 ...    36    14989
# 4                                                 ...   104    14990
# 5                                                 ...    85    14991
# 6                                                 ...    22    14992
# 7                                                 ...    19    14993
# 8                                                 ...    43    14994
# 9                                                 ...    44    14995
# 10                                                ...    47    14996
# 11                                                ...    30    14997
# 12                                                ...    20    14998
# 13                                                ...    98    14999
# 14                                                ...    62    15000
#
#                    post_time               scrape_time      tag       time  \
# 0   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:10 2017  awesome  1 day ago
# 1   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:10 2017  awesome  1 day ago
# 2   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:10 2017  awesome  1 day ago
# 3   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:11 2017  awesome  1 day ago
# 4   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:11 2017  awesome  1 day ago
# 5   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:12 2017  awesome  1 day ago
# 6   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:12 2017  awesome  1 day ago
# 7   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:12 2017  awesome  1 day ago
# 8   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:13 2017  awesome  1 day ago
# 9   Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:13 2017  awesome  1 day ago
# 10  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:13 2017  awesome  1 day ago
# 11  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:14 2017  awesome  1 day ago
# 12  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:14 2017  awesome  1 day ago
# 13  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:15 2017  awesome  1 day ago
# 14  Sun Mar 19 11:55:05 2017  Mon Mar 20 12:26:15 2017  awesome  1 day ago
# 0   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:17 2017  awesome  1 day ago
# 1   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:17 2017  awesome  1 day ago
# 2   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:17 2017  awesome  1 day ago
# 3   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:18 2017  awesome  1 day ago
# 4   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:18 2017  awesome  1 day ago
# 5   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:18 2017  awesome  1 day ago
# 6   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:19 2017  awesome  1 day ago
# 7   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:19 2017  awesome  1 day ago
# 8   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:19 2017  awesome  1 day ago
# 9   Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:20 2017  awesome  1 day ago
# 10  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:20 2017  awesome  1 day ago
# 11  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:20 2017  awesome  1 day ago
# 12  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:21 2017  awesome  1 day ago
# 13  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:21 2017  awesome  1 day ago
# 14  Sun Mar 19 11:55:07 2017  Mon Mar 20 12:26:21 2017  awesome  1 day ago
# ..                       ...                       ...      ...        ...
# 0   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 1   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 2   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 3   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 4   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 5   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:04 2017  awesome  1 day ago
# 6   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 7   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 8   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 9   Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 10  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 11  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 12  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 13  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 14  Sun Mar 19 12:21:15 2017  Mon Mar 20 13:50:05 2017  awesome  1 day ago
# 0   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 1   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 2   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 3   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 4   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 5   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 6   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 7   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:07 2017  awesome  1 day ago
# 8   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 9   Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 10  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 11  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 12  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 13  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 14  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
#
#                                user
# 0                        @anker1503
# 1                          @avindi_
# 2                         @jojoyees
# 3                     @keskincigdem
# 4                      @luisfernick
# 5                      @nath_pltn02
# 6                  @boshnastyphotos
# 7                  @likelikelike888
# 8                            @swmag
# 9                    @who_heartless
# 10                       @momo_choo
# 11                @daliycocopersian
# 12                        @foxgoods
# 13                          @juhwes
# 14                    @claucollazou
# 0                        @brennm222
# 1                  @talatkuafor1970
# 2                   @shotdamnxpixxs
# 3                   @lanostravita__
# 4                       @antohoppus
# 5                       @gjroya1225
# 6                     @sarinevasori
# 7                        @anker1503
# 8                          @avindi_
# 9                         @jojoyees
# 10                    @keskincigdem
# 11                     @luisfernick
# 12                     @nath_pltn02
# 13                 @boshnastyphotos
# 14                 @likelikelike888
# ..                              ...
# 0                 @antonio.apuzzo92
# 1                      @foxxsolaire
# 2                         @ilja_sen
# 3                    @sebatiptronic
# 4                    @alida.popescu
# 5                @beyond_landscapes
# 6                @bloody_marionette
# 7                      @whitedog.sk
# 8                            @vie51
# 9                      @eleonore__d
# 10            @thechickpeachickadee
# 11                  @kjeldgaardlene
# 12                   @norhan.ha.art
# 13                      @mariecoach
# 14  @myrose__77_hakareteblokeveceza
# 0             @norwegiannature_pics
# 1                      @zavodchenko
# 2                    @goldenlensguy
# 3               @irisvb_photography
# 4                   @goncharova_msk
# 5                     @nastasya_yuz
# 6                          @kaph_31
# 7                        @cat_ouska
# 8                 @blueeyesdesire90
# 9                     @oliviaszpirt
# 10                        @chefaisi
# 11                @antonio.apuzzo92
# 12                     @foxxsolaire
# 13                        @ilja_sen
# 14                   @sebatiptronic
#
# [15000 rows x 13 columns]

# %%
new_final.to_csv('Mon_Mar20.csv', encoding = 'utf-8')

# %% [markdown]
# Below is used to get the follower count

# %%
#ex users
users = ['silberstil','realdonaldtrump']
counts = []
for user in users:
    followers = requests.get('https://instaliga.com/' + str(user))
    text = BeautifulSoup(followers.text)
    for thing in text.find_all('div', {'class': "userInfo"}):
        counts.append(thing.find('div').text)
print counts
# Out:
# [u'423', u'3225', u'2691', u'1600', u'6277200', u'6']

# %%
pd.DataFrame([4,5,5])
# Out:
#    0
# 0  4
# 1  5
# 2  5

# %%
x = pd.read_csv('../../../Dropbox/photos/Mon Mar 20/new_Mar20.csv')
x
# Out:
#        Unnamed: 0                                            caption  \
# 0               0  \r\n                    Oh Konstanz 💕 #willmis...
# 1               1  \r\n                    #rosequartzmountain #s...
# 2               2  \r\n                    Amazing #sunset to a c...
# 3               3  \r\n                    Voyage into the myster...
# 4               4  \r\n                    #chile #instagood #nat...
# 5               5  \r\n                    Cra st désirat 😌 #xc #...
# 6               6  \r\n                    Grumpy fish. #nature #...
# 7               7  \r\n                    #flower #flowers #inst...
# 8               8  \r\n                    Stephanie Inn, Cannon ...
# 9               9  \r\n                    #şiir #şiirisevin #eni...
# 10             10  \r\n                    one of the more beauti...
# 11             11  \r\n                    La hora de jugar de Ti...
# 12             12  \r\n                    Nothing is better than...
# 13             13  \r\n                    Spring is on its way.\...
# 14             14  \r\n                    👌🖐 #pic #foto #fotogra...
# 15             15  \r\n                    "Draw a monster. Why i...
# 16             16  \r\n                    Örgülerce💎💎💎#hair #wed...
# 17             17  \r\n                    #beauty #sunset #sun #...
# 18             18  \r\n                    🌲🐾🐿 #love #nature #nat...
# 19             19  \r\n                    Amo questo posto !🔝 #S...
# 20             20  \r\n                    Suburban Sprawl \nTake...
# 21             21  \r\n                    Groove. Always. And. I...
# 22             22  \r\n                    Oh Konstanz 💕 #willmis...
# 23             23  \r\n                    #rosequartzmountain #s...
# 24             24  \r\n                    Amazing #sunset to a c...
# 25             25  \r\n                    Voyage into the myster...
# 26             26  \r\n                    #chile #instagood #nat...
# 27             27  \r\n                    Cra st désirat 😌 #xc #...
# 28             28  \r\n                    Grumpy fish. #nature #...
# 29             29  \r\n                    #flower #flowers #inst...
# ...           ...                                                ...
# 14970       14970  \r\n                    #mountain #sudtirol #l...
# 14971       14971  \r\n                    Today's stage 😍 #horse...
# 14972       14972  \r\n                    Great day, I'v been wi...
# 14973       14973  \r\n                    Look deep into nature,...
# 14974       14974  \r\n                    #garden #quince #delic...
# 14975       14975  \r\n                    That view! 😍\ncc: @sur...
# 14976       14976  \r\n                    "ocean blue, what have...
# 14977       14977  \r\n                    Castel Welsperg\n\nW H...
# 14978       14978  \r\n                    Canal des alpilles..\n...
# 14979       14979  \r\n                    Relax in the wood🍁\n.\...
# 14980       14980  \r\n                    The bees are all over ...
# 14981       14981  \r\n                    Har sku da det bedste ...
# 14982       14982  \r\n                    Untitled' new media ©N...
# 14983       14983  \r\n                    #laotzu #quotes #optim...
# 14984       14984  \r\n                    #nature #sky #sun #sum...
# 14985       14985  \r\n                    1/3 pics\n#water #pict...
# 14986       14986  \r\n                    #Эльбрус Спасибо #fuzb...
# 14987       14987  \r\n                    Grow.\n#plants #spring...
# 14988       14988  \r\n                    Nice weather @ the #be...
# 14989       14989  \r\n                    Dead Sea 🌊 бултыхаешьс...
# 14990       14990  \r\n                    😍\n#instagood#fashion#...
# 14991       14991  \r\n                    #cat #catlover #siusi ...
# 14992       14992  \r\n                    #walking #marche #natu...
# 14993       14993  \r\n                    Burning out another gi...
# 14994       14994  \r\n                    Not my photo 🌤☁️💛 #sun...
# 14995       14995  \r\n                    reggae falls 🇯🇲 @AppLe...
# 14996       14996  \r\n                    #mountain #sudtirol #l...
# 14997       14997  \r\n                    Today's stage 😍 #horse...
# 14998       14998  \r\n                    Great day, I'v been wi...
# 14999       14999  \r\n                    Look deep into nature,...
#
#        comments           filters  \
# 0           2.0     Filter Normal
# 1           0.0     Filter Normal
# 2           0.0     Filter Normal
# 3           4.0     Filter Normal
# 4           0.0     Filter Normal
# 5           0.0    Filter Mayfair
# 6           0.0     Filter Normal
# 7           0.0     Filter Normal
# 8           1.0     Filter Normal
# 9           0.0  Filter Clarendon
# 10          3.0  Filter Clarendon
# 11          4.0     Filter Normal
# 12          1.0     Filter Normal
# 13          1.0     Filter Normal
# 14          3.0       Filter Lark
# 15          0.0  Filter Clarendon
# 16          0.0     Filter Normal
# 17          2.0  Filter Clarendon
# 18          0.0     Filter Normal
# 19          3.0  Filter Clarendon
# 20          0.0    Filter Slumber
# 21          1.0     Filter Normal
# 22          2.0     Filter Normal
# 23          0.0     Filter Normal
# 24          0.0     Filter Normal
# 25          4.0     Filter Normal
# 26          0.0     Filter Normal
# 27          0.0    Filter Mayfair
# 28          0.0     Filter Normal
# 29          0.0     Filter Normal
# ...         ...               ...
# 14970       0.0     Filter Normal
# 14971       1.0     Filter Normal
# 14972       0.0     Filter Normal
# 14973       1.0     Filter Normal
# 14974       0.0     Filter Normal
# 14975       7.0     Filter Normal
# 14976       0.0     Filter Normal
# 14977       0.0       Filter Juno
# 14978       0.0      Filter Lo-fi
# 14979       0.0     Filter Normal
# 14980       6.0     Filter Normal
# 14981       0.0     Filter Normal
# 14982       0.0     Filter Normal
# 14983       0.0     Filter Normal
# 14984       0.0     Filter Normal
# 14985       0.0     Filter Normal
# 14986       0.0     Filter Normal
# 14987       0.0     Filter Normal
# 14988       0.0     Filter Normal
# 14989       5.0       Filter Lark
# 14990       2.0     Filter Normal
# 14991       0.0       Filter Juno
# 14992       0.0   Filter X-Pro II
# 14993       0.0   Filter Perpetua
# 14994       1.0     Filter Normal
# 14995       2.0     Filter Normal
# 14996       0.0     Filter Normal
# 14997       1.0     Filter Normal
# 14998       0.0     Filter Normal
# 14999       1.0     Filter Normal
#
#                                                 hashtags  \
Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
# 14999  Sun Mar 19 12:21:18 2017  Mon Mar 20 13:50:08 2017  awesome  1 day ago
#
#                                   user   new_id
# 0                           @anker1503  30000.0
# 1                             @avindi_  30001.0
# 2                            @jojoyees  30002.0
# 3                        @keskincigdem  30003.0
# 4                         @luisfernick  30004.0
# 5                         @nath_pltn02  30005.0
# 6                     @boshnastyphotos  30006.0
# 7                     @likelikelike888  30007.0
# 8                               @swmag  30008.0
# 9                       @who_heartless  30009.0
# 10                          @momo_choo  30010.0
# 11                   @daliycocopersian  30011.0
# 12                           @foxgoods  30012.0
# 13                             @juhwes  30013.0
# 14                       @claucollazou  30014.0
# 15                          @brennm222  30015.0
# 16                    @talatkuafor1970  30016.0
# 17                     @shotdamnxpixxs  30017.0
# 18                     @lanostravita__  30018.0
# 19                         @antohoppus  30019.0
# 20                         @gjroya1225  30020.0
# 21                       @sarinevasori  30021.0
# 22                          @anker1503  30022.0
# 23                            @avindi_  30023.0
# 24                           @jojoyees  30024.0
# 25                       @keskincigdem  30025.0
# 26                        @luisfernick  30026.0
# 27                        @nath_pltn02  30027.0
# 28                    @boshnastyphotos  30028.0
# 29                    @likelikelike888  30029.0
# ...                                ...      ...
# 14970                @antonio.apuzzo92  44970.0
# 14971                     @foxxsolaire  44971.0
# 14972                        @ilja_sen  44972.0
# 14973                   @sebatiptronic  44973.0
# 14974                   @alida.popescu  44974.0
# 14975               @beyond_landscapes  44975.0
# 14976               @bloody_marionette  44976.0
# 14977                     @whitedog.sk  44977.0
# 14978                           @vie51  44978.0
# 14979                     @eleonore__d  44979.0
# 14980            @thechickpeachickadee  44980.0
# 14981                  @kjeldgaardlene  44981.0
# 14982                   @norhan.ha.art  44982.0
# 14983                      @mariecoach  44983.0
# 14984  @myrose__77_hakareteblokeveceza  44984.0
# 14985            @norwegiannature_pics  44985.0
# 14986                     @zavodchenko  44986.0
# 14987                   @goldenlensguy  44987.0
# 14988              @irisvb_photography  44988.0
# 14989                  @goncharova_msk  44989.0
# 14990                    @nastasya_yuz  44990.0
# 14991                         @kaph_31  44991.0
# 14992                       @cat_ouska  44992.0
# 14993                @blueeyesdesire90  44993.0
# 14994                    @oliviaszpirt  44994.0
# 14995                        @chefaisi  44995.0
# 14996                @antonio.apuzzo92  44996.0
# 14997                     @foxxsolaire  44997.0
# 14998                        @ilja_sen  44998.0
# 14999                   @sebatiptronic  44999.0
#
# [15000 rows x 14 columns]

# %%
users = pd.DataFrame(x['user'])
type(users['user'][1])
[x for x in users['user']]
# Out:
# ['@anker1503',
#  '@avindi_',
#  '@jojoyees',
#  '@keskincigdem',
#  '@luisfernick',
#  '@nath_pltn02',
#  '@boshnastyphotos',
#  '@likelikelike888',
#  '@swmag',
#  '@who_heartless',
#  '@momo_choo',
#  '@daliycocopersian',
#  '@foxgoods',
#  '@juhwes',
#  '@claucollazou',
#  '@brennm222',
#  '@talatkuafor1970',
#  '@shotdamnxpixxs',
#  '@lanostravita__',
#  '@antohoppus',
#  '@gjroya1225',
#  '@sarinevasori',
#  '@anker1503',
#  '@avindi_',
#  '@jojoyees',
#  '@keskincigdem',
#  '@luisfernick',
#  '@nath_pltn02',
#  '@boshnastyphotos',
#  '@likelikelike888',
#  '@djukei',
#  '@rajakusa',
#  '@tonsoulrodrigo',
#  '@gelatunicorno',
#  '@wedder.reis',
#  '@nwayyu.aung.1',
#  '@emma.goldenretriever',
#  '@julieblnd',
#  '@emshidiq',
#  '@leamichellea',
#  '@divancti',
#  '@brennm222',
#  '@talatkuafor1970',
#  '@shotdamnxpixxs',
#  '@lanostravita__',
#  '@orquideas.eco.br',
#  '@whynotredesign',
#  '@carochop',
#  '@_epaphras_',
#  '@piscis21',
#  '@iryna_koshil',
#  '@northofthe6ix_',
#  '@ivansvukcevic',
#  '@truesouth180',
#  '@airwave_veter',
#  '@gurey_sha',
#  '@raphaeljunger',
#  '@kot.mao',
#  '@djukei',
#  '@rajakusa',
#  '@mrs_deia',
#  '@notesofthesoul',
#  '@electricmango_de',
#  '@antonellolosito',
#  '@gonzo_ras_al_ghul',
#  '@wander_luster_travels',
#  '@maqriehl',
#  '@orquideas.eco.br',
#  '@whynotredesign',
#  '@carochop',
#  '@_epaphras_',
#  '@piscis21',
#  '@iryna_koshil',
#  '@northofthe6ix_',
#  '@ivansvukcevic',
#  '@summerays._.spam',
#  '@qmilk_cosmetics',
#  '@mrs_deia',
#  '@notesofthesoul',
#  '@electricmango_de',
#  '@antonellolosito',
#  '@gonzo_ras_al_ghul',
#  '@wander_luster_travels',
#  '@maqriehl',
#  '@orquideas.eco.br',
#  '@whynotredesign',
#  '@carochop',
#  '@_epaphras_',
#  '@piscis21',
#  '@iryna_koshil',
#  '@hidepom80620',
#  '@cla.16',
#  '@mamanonthetrail',
#  '@herzens_momente',
#  '@summerays._.spam',
#  '@qmilk_cosmetics',
#  '@mrs_deia',
#  '@notesofthesoul',
#  '@electricmango_de',
#  '@antonellolosito',
#  '@gonzo_ras_al_ghul',
#  '@wander_luster_travels',
#  '@maqriehl',
#  '@orquideas.eco.br',
#  '@whynotredesign',
#  '@bethjade__',
#  '@the_nature_of_photography',
#  '@tjh_lordphotography',
#  '@hidepom80620',
#  '@cla.16',
#  '@mamanonthetrail',
#  '@herzens_momente',
#  '@summerays._.spam',
#  '@qmilk_cosmetics',
#  '@mrs_deia',
#  '@notesofthesoul',
#  '@electricmango_de',
#  '@antonellolosito',
#  '@gonzo_ras_al_ghul',
#  '@wander_luster_travels',
#  '@pascalhaag',
#  '@threepointshots',
#  '@baikalresidence',
#  '@flower_house_kh',
#  '@photos_by_kashi',
#  '@ukrainianimmigrant',
#  '@allworld82',
#  '@zvetkova007',
#  '@bethjade__',
#  '@the_nature_of_photography',
#  '@tjh_lordphotography',
#  '@hidepom80620',
#  '@cla.16',
#  '@mamanonthetrail',
#  '@herzens_momente',
#  '@fede_finocchiaro_',
#  '@alexander_luperon',
#  '@kazz.06',
#  '@ebanistadeibiza',
#  '@pascalhaag',
#  '@threepointshots',
#  '@baikalresidence',
#  '@flower_house_kh',
#  '@photos_by_kashi',
#  '@ukrainianimmigrant',
#  '@allworld82',
#  '@zvetkova007',
#  '@bethjade__',
#  '@the_nature_of_photography',
#  '@tjh_lordphotography',
#  '@ivan.defreitas',
#  '@hayleyceee',
#  '@megroll13',
#  '@deny81raciti',
#  '@anakyn',
#  '@powerofwildlife',
#  '@terjeaas',
#  '@simo_fo',
#  '@fede_finocchiaro_',
#  '@alexander_luperon',
#  '@kazz.06',
#  '@ebanistadeibiza',
#  '@pascalhaag',
#  '@threepointshots',
#  '@baikalresidence',
#  '@jawhara888',
#  '@s.alisa.a',
#  '@aashish_abin_eipe',
#  '@silvie1306',
#  '@thegrungerisback',
#  '@tamouna_khazhalia',
#  '@ivan.defreitas',
#  '@hayleyceee',
#  '@megroll13',
#  '@deny81raciti',
#  '@anakyn',
#  '@powerofwildlife',
#  '@terjeaas',
#  '@simo_fo',
#  '@fede_finocchiaro_',
#  '@crashedintomyself',
#  '@boombingoworld',
#  '@roussel.juliette__',
#  '@goschka27',
#  '@mapltravel',
#  '@colbiolegscv',
#  '@chriskaz1993',
#  '@great_ivity',
#  '@pencetshutter',
#  '@plunge.travel',
#  '@hakulinenjarmo',
#  '@jawhara888',
#  '@s.alisa.a',
#  '@aashish_abin_eipe',
#  '@silvie1306',
#  '@avrahamyadan',
#  '@yolandawestby_',
#  '@spartacus.39',
#  '@arushi.45',
#  '@thatredheadsarah',
#  '@crashedintomyself',
#  '@boombingoworld',
#  '@roussel.juliette__',
#  '@goschka27',
#  '@mapltravel',
#  '@colbiolegscv',
#  '@chriskaz1993',
#  '@great_ivity',
#  '@pencetshutter',
#  '@plunge.travel',
#  '@akhil_j_nair_',
#  '@lulu_and_nature',
#  '@avrahamyadan',
#  '@yolandawestby_',
#  '@spartacus.39',
#  '@arushi.45',
#  '@thatredheadsarah',
#  '@crashedintomyself',
#  '@boombingoworld',
#  '@roussel.juliette__',
#  '@goschka27',
#  '@mapltravel',
#  '@colbiolegscv',
#  '@chriskaz1993',
#  '@great_ivity',
#  '@thedyingstars',
#  '@nickpryme',
#  '@007_flower_700',
#  '@letsmakethemostofit',
#  '@vishnunath2000',
#  '@akhil_j_nair_',
#  '@lulu_and_nature',
#  '@avrahamyadan',
#  '@yolandawestby_',
#  '@spartacus.39',
#  '@arushi.45',
#  '@thatredheadsarah',
#  '@crashedintomyself',
#  '@boombingoworld',
#  '@roussel.juliette__',
#  '@bonnie8216',
#  '@jedapearl',
#  '@etulupov',
#  '@marcolotter',
#  '@thedyingstars',
#  '@nickpryme',
#  '@007_flower_700',
#  '@letsmakethemostofit',
#  '@vishnunath2000',
#  '@akhil_j_nair_',
#  '@lulu_and_nature',
#  '@avrahamyadan',
#  '@yolandawestby_',
#  '@spartacus.39',
#  '@arushi.45',
#  '@miss_urban_exploration',
#  '@l_n_happysnaps',
#  '@chefaisi',
#  '@loclug',
#  '@bonnie8216',
#  '@jedapearl',
#  '@etulupov',
#  '@marcolotter',
#  '@thedyingstars',
#  '@nickpryme',
#  '@007_flower_700',
#  '@letsmakethemostofit',
#  '@vishnunath2000',
#  '@akhil_j_nair_',
#  '@lulu_and_nature',
#  '@loisghost',
#  '@teddy__phantom',
#  '@dasimple.things',
#  '@basilbw06',
#  '@miss_urban_exploration',
#  '@l_n_happysnaps',
#  '@chefaisi',
#  '@loclug',
#  '@bonnie8216',
#  '@jedapearl',
#  '@etulupov',
#  '@marcolotter',
#  '@thedyingstars',
#  '@nickpryme',
#  '@007_flower_700',
#  '@__bountybobo__',
#  '@nyleve_kif27',
#  '@lindsraymond',
#  '@o.t.r.outdoors',
#  '@pictrus',
#  '@naturaleza.micro.hd',
#  '@dfainsta',
#  '@photogrxphist',
#  '@theshenman',
#  '@loisghost',
#  '@teddy__phantom',
#  '@dasimple.things',
#  '@basilbw06',
#  '@miss_urban_exploration',
#  '@l_n_happysnaps',
#  '@beautiful_n_a_t_u_re',
#  '@rabidgrime83',
#  '@corrie_carpediem',
#  '@pasqbr_27',
#  '@mrc.l',
#  '@lesleyhk88',
#  '@__bountybobo__',
#  '@nyleve_kif27',
#  '@lindsraymond',
#  '@o.t.r.outdoors',
#  '@pictrus',
#  '@naturaleza.micro.hd',
#  '@dfainsta',
#  '@photogrxphist',
#  '@theshenman',
#  '@fowcemetery',
#  '@moonthego',
#  '@ne.ungulateguardian',
#  '@ldnxgrt',
#  '@4ro_georgi',
#  '@luca6376',
#  '@due_mici_uno_spitz',
#  '@molskielim',
#  '@helenaninni',
#  '@beautiful_n_a_t_u_re',
#  '@rabidgrime83',
#  '@corrie_carpediem',
#  '@pasqbr_27',
#  '@mrc.l',
#  '@lesleyhk88',
#  '@behatilife',
#  '@heartrockcreative',
#  '@saguibruno',
#  '@alexandrezys',
#  '@irenelauretti',
#  '@stern_ann_an',
#  '@ira.harchenko.90',
#  '@habana.macro',
#  '@fowcemetery',
#  '@moonthego',
#  '@ne.ungulateguardian',
#  '@ldnxgrt',
#  '@4ro_georgi',
#  '@luca6376',
#  '@due_mici_uno_spitz',
#  '@cornishgirlabroad',
#  '@adolfostark',
#  '@_meryam_r',
#  '@moments_inphotos',
#  '@behatilife',
#  '@heartrockcreative',
#  '@saguibruno',
#  '@alexandrezys',
#  '@irenelauretti',
#  '@stern_ann_an',
#  '@ira.harchenko.90',
#  '@habana.macro',
#  '@fowcemetery',
#  '@moonthego',
#  '@ne.ungulateguardian',
#  '@justoneperday',
#  '@naliz_ar',
#  '@didou_naia',
#  '@nofar_ziprut',
#  '@rayschaefer',
#  '@nagoh',
#  '@zeyneptt556',
#  '@roussel.juliette__',
#  '@taidelytukyte',
#  '@cornishgirlabroad',
#  '@adolfostark',
#  '@_meryam_r',
#  '@moments_inphotos',
#  '@behatilife',
#  '@heartrockcreative',
#  '@the.overxposed',
#  '@pipoca.bulldog',
#  '@pixelcharlotte',
#  '@__.pally.__',
#  '@health_life30',
#  '@termeszet.photo',
#  '@shaun.m7',
#  '@justoneperday',
#  '@naliz_ar',
#  '@didou_naia',
#  '@nofar_ziprut',
#  '@rayschaefer',
#  '@nagoh',
#  '@zeyneptt556',
#  '@roussel.juliette__',
#  '@derya.barcin',
#  '@afarukkarakus',
#  '@bibi_morins',
#  '@n_aturex',
#  '@the.overxposed',
#  '@pipoca.bulldog',
#  '@pixelcharlotte',
#  '@__.pally.__',
#  '@health_life30',
#  '@termeszet.photo',
#  '@shaun.m7',
#  '@justoneperday',
#  '@naliz_ar',
#  '@didou_naia',
#  '@nofar_ziprut',
#  '@tatuanya888',
#  '@marialena_et',
#  '@hana_el30',
#  '@cameliayoga',
#  '@sygoldstein',
#  '@violet_sky00',
#  '@alhapazanzibar',
#  '@_pure._.nature_',
#  '@derya.barcin',
#  '@afarukkarakus',
#  '@bibi_morins',
#  '@n_aturex',
#  '@the.overxposed',
#  '@pipoca.bulldog',
#  '@pixelcharlotte',
#  '@funnyvideos.16',
#  '@kinakanu',
#  '@mattrossofficial',
#  '@tatuanya888',
#  '@marialena_et',
#  '@hana_el30',
#  '@cameliayoga',
#  '@sygoldstein',
#  '@violet_sky00',
#  '@alhapazanzibar',
#  '@_pure._.nature_',
#  '@derya.barcin',
#  '@afarukkarakus',
#  '@bibi_morins',
#  '@n_aturex',
#  '@daikiti0920',
#  '@haqsarabi',
#  '@karen.morgan8308',
#  '@______chus______',
#  '@sailbel',
#  '@funnyvideos.16',
#  '@kinakanu',
#  '@mattrossofficial',
#  '@tatuanya888',
#  '@marialena_et',
#  '@hana_el30',
#  '@cameliayoga',
#  '@sygoldstein',
#  '@violet_sky00',
#  '@alhapazanzibar',
#  '@neeirox',
#  '@mandelkaa',
#  '@robertobezz',
#  '@jesusmamr',
#  '@kungfu_xiaona',
#  '@marios.art',
#  '@daikiti0920',
#  '@haqsarabi',
#  '@karen.morgan8308',
#  '@______chus______',
#  '@sailbel',
#  '@funnyvideos.16',
#  '@kinakanu',
#  '@mattrossofficial',
#  '@tatuanya888',
#  '@barbariska_photo',
#  '@sam_hockaday',
#  '@tiffin_unboxed',
#  '@walking.barefoot',
#  '@tomislavvisal',
#  '@sormunentoni',
#  '@yavelena',
#  '@qatarenature',
#  '@annajadwigamagdalenairena',
#  '@roxs_love',
#  '@neeirox',
#  '@mandelkaa',
#  '@robertobezz',
#  '@jesusmamr',
#  '@kungfu_xiaona',
#  '@korothesayanchow',
#  '@bonton_pascarellagiada',
#  '@hike.up',
#  '@barbariska_photo',
#  '@sam_hockaday',
#  '@tiffin_unboxed',
#  '@walking.barefoot',
#  '@tomislavvisal',
#  '@sormunentoni',
#  '@yavelena',
#  '@qatarenature',
#  '@annajadwigamagdalenairena',
#  '@roxs_love',
#  '@neeirox',
#  '@mandelkaa',
#  '@gizlibahcelerimiz',
#  '@anitaseaview',
#  '@termeszet.photo',
#  '@besevenb7',
#  '@karlossek.v',
#  '@bertrandmatheo',
#  '@korothesayanchow',
#  '@bonton_pascarellagiada',
#  '@hike.up',
#  '@barbariska_photo',
#  '@sam_hockaday',
#  '@tiffin_unboxed',
#  '@walking.barefoot',
#  '@tomislavvisal',
#  '@sormunentoni',
#  '@suepruesf',
#  '@wocante.waste',
#  '@nationale7',
#  '@nataliafree',
#  '@melaniebugsy',
#  '@treelinehikingco',
#  '@_southman_',
#  '@sylarzalmon',
#  '@all.about.universe',
#  '@angieelanina',
#  '@bellina.photography',
#  '@albe_grigio',
#  '@fatmaalhabtoor',
#  '@gizlibahcelerimiz',
#  '@anitaseaview',
#  '@reaching_for_the_summit',
#  '@selinanand',
#  '@proutlord',
#  '@annettedr14',
#  '@sebastiangronwall',
#  '@thorecht',
#  '@ankaw',
#  '@paulinimissi',
#  '@minabujo',
#  '@believe_quotes1994',
#  '@maeliss_s',
#  '@suepruesf',
#  '@wocante.waste',
#  '@nationale7',
#  '@nataliafree',
#  '@karlita_zam',
#  '@chrissie_schmidt',
#  '@yilmaz.sensozlu',
#  '@carminabuendia',
#  '@raghav.behani',
#  '@theprettypoetic',
#  '@reaching_for_the_summit',
#  '@selinanand',
#  '@proutlord',
#  '@annettedr14',
#  '@sebastiangronwall',
#  '@thorecht',
#  '@ankaw',
#  '@paulinimissi',
#  '@minabujo',
#  '@themoderndavinci',
#  '@cynthia_takacs',
#  '@yoshiko_jiazi',
#  '@trashhoez2018',
#  '@cfvcarol',
#  '@lpikachul',
#  '@_rxse_photography',
#  '@karlita_zam',
#  '@chrissie_schmidt',
#  '@yilmaz.sensozlu',
#  '@carminabuendia',
#  '@raghav.behani',
#  '@theprettypoetic',
#  '@reaching_for_the_summit',
#  '@selinanand',
#  '@inmyelement2',
#  '@stupidfoxes',
#  '@alessiamaritano',
#  '@jeanniedht',
#  '@nursakty',
#  '@akasorakrit',
#  '@ben_steger_',
#  '@themoderndavinci',
#  '@cynthia_takacs',
#  '@yoshiko_jiazi',
#  '@trashhoez2018',
#  '@cfvcarol',
#  '@lpikachul',
#  '@_rxse_photography',
#  '@karlita_zam',
#  '@wanderbeer',
#  '@_samantha_pi',
#  '@silvanavargas_us',
#  '@ayse.er.topal',
#  '@inmyelement2',
#  '@stupidfoxes',
#  '@alessiamaritano',
#  '@jeanniedht',
#  '@nursakty',
#  '@akasorakrit',
#  '@ben_steger_',
#  '@themoderndavinci',
#  '@cynthia_takacs',
#  '@yoshiko_jiazi',
#  '@trashhoez2018',
#  '@rodrigo_soria_fotografia',
#  '@sarosalehi1371',
#  '@usheda',
#  '@ruflussfoodie',
#  '@lifewithgriff',
#  '@rohitt9993',
#  '@wanderbeer',
#  '@_samantha_pi',
#  '@silvanavargas_us',
#  '@ayse.er.topal',
#  '@inmyelement2',
#  '@stupidfoxes',
#  '@alessiamaritano',
#  '@jeanniedht',
#  '@nursakty',
#  '@zeynepoztayinci',
#  '@kathrynparsons_art',
#  '@winter_triumph',
#  '@sandra_7394',
#  '@sigitos',
#  '@carlobattillocchi',
#  '@eiriichii',
#  '@rodrigo_soria_fotografia',
#  '@sarosalehi1371',
#  '@usheda',
#  '@ruflussfoodie',
#  '@lifewithgriff',
#  '@rohitt9993',
#  '@wanderbeer',
#  '@_samantha_pi',
#  '@peachangelicc',
#  '@beitaamarcos',
#  '@cutish_queen',
#  '@ashh_rain_13',
#  '@tribunskaya_karina',
#  '@steven_gori',
#  '@tobinagler',
#  '@zeynepoztayinci',
#  '@kathrynparsons_art',
#  '@winter_triumph',
#  '@sandra_7394',
#  '@sigitos',
#  '@carlobattillocchi',
#  '@eiriichii',
#  '@rodrigo_soria_fotografia',
#  '@carlb_pictures',
#  '@prg_fit',
#  '@ristiana_putri19',
#  '@lisa_glt',
#  '@nihat_kymz_photography',
#  '@peachangelicc',
#  '@beitaamarcos',
#  '@cutish_queen',
#  '@ashh_rain_13',
#  '@tribunskaya_karina',
#  '@steven_gori',
#  '@tobinagler',
#  '@zeynepoztayinci',
#  '@kathrynparsons_art',
#  '@winter_triumph',
#  '@stella.review',
#  '@nuvola_sunset',
#  '@tarantodamare',
#  '@amfine.thankyou.andyou',
#  '@naturaleza.micro.hd',
#  '@andresaorchid',
#  '@beerandelle',
#  '@diamantes.tranquilos',
#  '@carlb_pictures',
#  '@prg_fit',
#  '@ristiana_putri19',
#  '@lisa_glt',
#  '@nihat_kymz_photography',
#  '@peachangelicc',
#  '@beitaamarcos',
#  '@edvintun',
#  '@kris.stoop',
#  '@martinjunio',
#  '@tatianysiilvaa',
#  '@mammabearsworld',
#  '@stella.review',
#  '@nuvola_sunset',
#  '@tarantodamare',
#  '@amfine.thankyou.andyou',
#  '@naturaleza.micro.hd',
#  '@andresaorchid',
#  '@beerandelle',
#  '@diamantes.tranquilos',
#  '@carlb_pictures',
#  '@prg_fit',
#  '@mr._freedom',
#  '@yankatatianka',
#  '@chlow_93',
#  '@himanshuher',
#  '@edvintun',
#  '@kris.stoop',
#  '@martinjunio',
#  '@tatianysiilvaa',
#  '@mammabearsworld',
#  '@stella.review',
#  '@nuvola_sunset',
#  '@tarantodamare',
#  '@amfine.thankyou.andyou',
#  '@naturaleza.micro.hd',
#  '@andresaorchid',
#  '@tanya_bankeri',
#  '@gkanitz',
#  '@lauriewildkat',
#  '@blelop',
#  '@tiscarenno',
#  '@dinver_neiv',
#  '@mikerutzen',
#  '@mrjaylazarte',
#  '@jenny.huyghe',
#  '@pilarmedina62',
#  '@paum_07',
#  '@katimagioielli',
#  '@clajan_',
#  '@simon95k',
#  '@federico_quaglia',
#  '@tattooknux1',
#  '@federica_porrovecchio',
#  '@gonaturalwithbu',
#  '@di_fire11',
#  '@earthofnat',
#  '@federica_rfc',
#  '@sndretta',
#  '@tanya_bankeri',
#  '@gkanitz',
#  '@lauriewildkat',
#  '@blelop',
#  '@tiscarenno',
#  '@dinver_neiv',
#  '@mikerutzen',
#  '@mrjaylazarte',
#  '@martinidzier',
#  '@a_hikers_view',
#  '@monolibis',
#  '@fabianasalomao',
#  '@totopoz',
#  '@usheda',
#  '@termeszet.photo',
#  '@tattooknux1',
#  '@federica_porrovecchio',
#  '@gonaturalwithbu',
#  '@di_fire11',
#  '@earthofnat',
#  '@federica_rfc',
#  '@sndretta',
#  '@tanya_bankeri',
#  '@shots_and_sketches',
#  '@_schmidt_fotografie',
#  '@martinidzier',
#  '@a_hikers_view',
#  '@monolibis',
#  '@fabianasalomao',
#  '@totopoz',
#  '@usheda',
#  '@termeszet.photo',
#  '@tattooknux1',
#  '@federica_porrovecchio',
#  '@gonaturalwithbu',
#  '@di_fire11',
#  '@earthofnat',
#  '@federica_rfc',
#  '@spanischunddeutsch',
#  '@lamauti',
#  '@ladyxrose1',
#  '@_jeanmarc_',
#  '@denisca.s',
#  '@karina.andra',
#  '@shots_and_sketches',
#  '@_schmidt_fotografie',
#  '@martinidzier',
#  '@a_hikers_view',
#  '@monolibis',
#  '@fabianasalomao',
#  '@totopoz',
#  '@usheda',
#  '@termeszet.photo',
#  '@raffyyankeedollar',
#  '@ladymushrooom',
#  '@ericdreams',
#  '@chamarcelino_art',
#  '@spanischunddeutsch',
#  '@lamauti',
#  '@ladyxrose1',
#  '@_jeanmarc_',
#  '@denisca.s',
#  '@karina.andra',
#  '@shots_and_sketches',
#  '@_schmidt_fotografie',
#  '@martinidzier',
#  '@a_hikers_view',
#  '@monolibis',
#  '@alidialice0382',
#  '@effebarker',
#  '@ateljeach',
#  '@_di8851_',
#  '@raffyyankeedollar',
#  '@ladymushrooom',
#  '@ericdreams',
#  '@chamarcelino_art',
#  '@spanischunddeutsch',
#  '@lamauti',
#  '@ladyxrose1',
#  '@_jeanmarc_',
#  '@denisca.s',
#  '@karina.andra',
#  '@shots_and_sketches',
#  '@staaar_studio',
#  '@zara2lifefashion',
#  '@onryldirim',
#  '@rubyandleia',
#  '@zheniiz',
#  '@susetiyoko',
#  '@lafdali.sara',
#  '@gebruzen',
#  '@e2the3',
#  '@alidialice0382',
#  '@effebarker',
#  '@ateljeach',
#  '@_di8851_',
#  '@raffyyankeedollar',
#  '@ladymushrooom',
#  '@ellyinar',
#  '@davidwhardy',
#  '@follow_islamic_path',
#  '@chateauroquefort',
#  '@little_yuppie',
#  '@kenfolan',
#  '@staaar_studio',
#  '@zara2lifefashion',
#  '@onryldirim',
#  '@rubyandleia',
#  '@zheniiz',
#  '@susetiyoko',
#  '@lafdali.sara',
#  '@gebruzen',
#  '@e2the3',
#  '@vinay_reddy89',
#  '@jodiecollisson',
#  '@natali_svk',
#  '@rat_inside',
#  '@pajador',
#  '@bushbabyk8',
#  '@nutrirelser',
#  '@valeria_cattiveria',
#  '@mikedaish',
#  '@goutte___',
#  '@erandnebo',
#  '@ellyinar',
#  '@davidwhardy',
#  '@follow_islamic_path',
#  '@chateauroquefort',
#  '@dimitrijetanaskovic',
#  '@bingwallpapers',
#  '@zeynepoztayinci',
#  '@bexkollstedt',
#  '@orange_nasturtiums',
#  '@alexandra_bouchaard',
#  '@hayleyinparis',
#  '@waybywater',
#  '@vinay_reddy89',
#  '@jodiecollisson',
#  '@natali_svk',
#  '@rat_inside',
#  '@pajador',
#  '@bushbabyk8',
#  '@nutrirelser',
#  '@_albert._',
#  '@s.a.r.a.1.9.8.9',
#  '@batsinthespookery',
#  '@saralemac',
#  '@cree_ative_ink',
#  '@dimitrijetanaskovic',
#  '@bingwallpapers',
#  '@zeynepoztayinci',
#  '@bexkollstedt',
#  '@orange_nasturtiums',
#  '@alexandra_bouchaard',
#  '@hayleyinparis',
#  '@waybywater',
#  '@vinay_reddy89',
#  '@jodiecollisson',
#  '@sevalseval',
#  '@alexanderdennon',
#  '@fellows_annamaetion',
#  '@linda_botter',
#  '@yuri7638',
#  '@simply6.0',
#  '@jawhara888',
#  '@cornishmadematt',
#  '@_albert._',
#  '@s.a.r.a.1.9.8.9',
#  '@batsinthespookery',
#  '@saralemac',
#  '@cree_ative_ink',
#  '@dimitrijetanaskovic',
#  '@bingwallpapers',
#  '@abby.rosephotography',
#  '@hasib.rassa',
#  '@hwyadenfarm',
#  '@mariobarriosc',
#  '@juan_pedro_5',
#  '@liaselina',
#  '@thekefircompany',
#  '@majkl_kovac_',
#  '@v.kazlauskaite',
#  '@sevalseval',
#  '@alexanderdennon',
#  '@fellows_annamaetion',
#  '@linda_botter',
#  '@yuri7638',
#  '@simply6.0',
#  '@vriniotis',
#  '@fantastic_life_inc',
#  '@denissaijo',
#  '@mariamelisa87',
#  '@raquel_amarante',
#  '@ameemart_',
#  '@_life_enjoyer',
#  '@abby.rosephotography',
#  '@hasib.rassa',
#  '@hwyadenfarm',
#  '@mariobarriosc',
#  '@juan_pedro_5',
#  '@liaselina',
#  '@thekefircompany',
#  '@majkl_kovac_',
#  '@yunmintan',
#  '@ashleyfiona93',
#  '@pillergiulia',
#  '@cosymezher',
#  '@barbaricbastard',
#  '@cherry.stars',
#  '@_viki_91',
#  '@vriniotis',
#  '@fantastic_life_inc',
#  '@denissaijo',
#  '@mariamelisa87',
#  '@raquel_amarante',
#  '@ameemart_',
#  '@_life_enjoyer',
#  '@abby.rosephotography',
#  '@ninz.am',
#  '@woodland_tea_party',
#  '@rob.vanloon',
#  '@corrie_carpediem',
#  '@skinmomentss',
#  '@incredica',
#  '@prasanthgrao',
#  '@kingabarth_',
#  '@justindaniels93',
#  '@yunmintan',
#  '@ashleyfiona93',
#  '@pillergiulia',
#  '@cosymezher',
#  '@barbaricbastard',
#  '@cherry.stars',
#  '@fotografie_daniela',
#  '@intheyear9595',
#  '@j_gong',
#  '@ale_fourteen',
#  '@lynn803',
#  '@mgmaigaart',
#  '@ten10nyan',
#  '@pieracastaldo',
#  '@skzubairhaque',
#  '@sergiswhite',
#  '@ninz.am',
#  '@woodland_tea_party',
#  '@rob.vanloon',
#  '@corrie_carpediem',
#  '@skinmomentss',
#  '@matevzpetrovic',
#  '@krait_marais',
#  '@ber_77',
#  '@thesparkleblog',
#  '@micella83',
#  '@fotografie_daniela',
#  '@intheyear9595',
#  '@j_gong',
#  '@ale_fourteen',
#  '@lynn803',
#  '@mgmaigaart',
#  '@ten10nyan',
#  '@pieracastaldo',
#  '@skzubairhaque',
#  '@sergiswhite',
#  '@marinadobic',
#  '@eliancik',
#  '@yuri_emma',
#  '@marcoceccarelli',
#  '@sig_upcycling',
#  '@me_le_ginger',
#  '@mdmduran',
#  '@matevzpetrovic',
#  '@krait_marais',
#  '@ber_77',
#  ...]

# %%
users = pd.DataFrame([hwat.replace('@','') for hwat in users['user']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b2219752c3b4> in <module>()
# ----> 1 users = pd.DataFrame([hwat.replace('@','') for hwat in users['user']])
#
# <ipython-input-31-b2219752c3b4> in <listcomp>(.0)
# ----> 1 users = pd.DataFrame([hwat.replace('@','') for hwat in users['user']])
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
users.to_csv('user_Mar18.csv')

# %%
users[0][users[0] == 'blue_bunch']
# Out:
# 4307    blue_bunch
# 4327    blue_bunch
# 4348    blue_bunch
# Name: 0, dtype: object

# %%
x = users[0].unique()
len(users[0].unique())
# Out:
# 6867

# %%
[i for i,y in enumerate(x) if y == 'loveandtacosxo']
# Out:
# [3989]

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-69-f4ec87d09cda> in <module>()
# ----> 1 from scrub import scrub
#
# ImportError: No module named scrub
