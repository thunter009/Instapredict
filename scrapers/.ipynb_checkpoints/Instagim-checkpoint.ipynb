# %% [markdown]
# First, we want to load packages and create an empty data frame to be filled. Additionally, define a starter key to collect more keys

# %%
import requests
import json
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import time 
import datetime
final = pd.DataFrame(columns = ['caption','comments','filters','hashtags','image','photo_id','likes','time','user', 'scrape_time', 'key', 'tag']) 
#chance this key will have to be changed over time - atm it's just to start collecting other keys
key = 'AQDt5LYE7lbm7Rb2P-ox-rkpSdXXT19HsvYz4Ncf_k2qcjJ3S2crfI9m-jipFD0SOtWBTAIEKkU1AozNIhN52-wfgMbUTr1biNafa9RGWnQpF6izIF8GIiNf1Dvdl_IbnR4'
counter = 0

# %% [markdown]
# Only run the code below if you're looking to get more keys. The number of keys you get will depend on the range

# %%
#collect keys
start = time.time()
result = []  
for i in range(0,1000):
    d = {}
    response = requests.post("http://www.instagim.com/ajax/",
        data='get_photos=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%' + key + '%count%3D15%26access_token%3D&next_url=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D%7Bnext_key%7D%26count%3D15%26access_token%3D',
        headers={
            "Accept": "application/json, text/javascript, */*; q=0.01",
            "Accept-Encoding": "gzip, deflate",
            "Accept-Language": "en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4",
            "Connection": "keep-alive",
            "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
            "Origin": "http://www.instagim.com",
            "Referer": "http://www.instagim.com/tag/awesome",
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
            "X-Requested-With": "XMLHttpRequest"
        },
        cookies={
            "_ga": "GA1.2.821769385.1489495570",
            "_gat": "1"
        },
    )
    data = json.loads(response.text)
    d['key'] = data['key'].encode('utf-8')
    d['post_time'] = str(time.strftime("%c"))
    d['tag'] = 'awesome'
    result.append(d)

    
print 'Time elapsed: ', time.time() - start
# Out:
# Time elapsed:  5.24636387825

# %% [markdown]
# Simply writing the keys to a csv file while the photos "mature" like fine wine.

# %%
keys_df = pd.DataFrame(result)
print keys_df.head()
#keys_df.to_csv('keys'+ str(time.strftime("%c") + '.csv'))
# Out:
#                                                  key  \
# 0  AQDBHxLIYZTVS_PLqyS7V204fD62YeXAoB35NuCoxDPM9P...
# 1  AQAbMhPULDyVLUXa8oAJ7ck7Ss_iNhaWEPkSmuoDD3nb2b...
#
#                   post_time      tag
# 0  Sun Mar 19 11:54:31 2017  awesome
# 1  Sun Mar 19 11:54:33 2017  awesome

# %% [markdown]
# Now, we want to use yesterdays keys to actually get the data we want.

# %%
key = pd.read_csv('../data/keysThuMar1621_50_502017.csv')
key = key.drop('Unnamed: 0', axis = 1)
key = key.iloc[1:3,:] # for tests
key
# Out:
#                                                  key                 post_time
# 1  AQDRTq-5ApHwFi46pm-JqK-kV15oqfHetPM0JQxNfI1_oC...  Thu Mar 16 21:12:26 2017
# 2  AQBFhfQpX01OEMbexcfDu1TDZHw8u8rca7PGaYEZEibrjC...  Thu Mar 16 21:12:28 2017

# %% [markdown]
# Extract the photos from each key

# %%
for index,row in key.iterrows():
    
    response = requests.post("http://www.instagim.com/ajax/",
        data='get_photos=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D' + row['key'] + '%26count%3D15%26access_token%3D&next_url=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D%7Bnext_key%7D%26count%3D15%26access_token%3D',
        headers={
            "Accept": "application/json, text/javascript, */*; q=0.01",
            "Accept-Encoding": "gzip, deflate",
            "Accept-Language": "en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4",
            "Connection": "keep-alive",
            "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
            "Origin": "http://www.instagim.com",
            "Referer": "http://www.instagim.com/tag/nature",
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
            "X-Requested-With": "XMLHttpRequest"
        },
        cookies={
            "_ga": "GA1.2.821769385.1489495570",
            "_gat": "1"
        },
    )

    data = json.loads(response.text)
    text = BeautifulSoup(data['html'], 'html.parser')
    events = text.find_all('div', {'class': "box-photo"})


    result = [] 
    for event in events:
        counter += 1
        d = {} # each event is its own dictionary so initialize it inside the loop
        try: #use try statement so code doesn't break if names are wrong
                 #remember to change this to a counter
                index = counter
                im = [x['src'] for x in event.find('div', {'class': 'photo'}).a][0]
                urllib.urlretrieve(im, str(counter) + ".jpg")
                time_post = event.find('div', {'class': "upload-time"}).get_text()
                user = event.find('div', {'class': "username"}).a.get_text()
                capt = event.find('div', {'class': "photo-description"}).get_text()
                hashtags = event.find('div', {'class': "photo-tags"}).get_text()
                filters = event.find('div', {'class': "filter-text"}).get_text()
                likes = event.find('span', {'class': "icon-thumbs-up-alt"}).get_text()
                comments = event.find('span', {'class': "icon-chat"}).get_text()
        except: 
                index = ""
                im = ""
                time_post = ""
                user = ""
                capt = ""
                hashtags = ""
                filters = ""
                likes = ""
                comments = ""
        finally:  
                d['photo_id'] = index
                d['image'] = im
                d['time'] = time_post
                d['user'] = user             
                d['caption'] = capt
                d['hashtags'] = hashtags
                d['filters'] = filters
                d['likes'] = likes
                d['comments'] = comments
                d['scrape_time'] = str(time.strftime("%c"))
                d['post_time'] = row['post_time']
                d['key'] = key
                d['tag'] = 'nature'
                result.append(d) # each event is own dictionary

    final = final.append(pd.DataFrame(result))

# %% [markdown]
# Double check that your dataframe has been created

# %%
final
# Out:
#                                               caption comments  \
# 0   \r\n                    #photo #photography #p...        1
# 1   \r\n                    #creativesma #nature #...        2
# 2   \r\n                    #photography #photogra...        4
# 3   \r\n                    봉은사 홍매화  with Leica SL...        0
# 4   \r\n                    Selamat pagi kyai dan ...        0
# 5   \r\n                    #emo#scene#goth#black#...        1
# 6   \r\n                    #photography #photowit...        0
# 7   \r\n                    Another side of the ro...        2
# 8   \r\n                    The girls are about ha...        0
# 9   \r\n                    #sunrise #sunset #sun ...        2
# 10  \r\n                    #GullLyfe Gorgeous day...        0
# 11  \r\n                    Deer Crossing the stre...        0
# 12  \r\n                    Los Angeles #losangele...        0
# 13  \r\n                    I stare at mum when I ...        4
# 14  \r\n                    Wonderful sunset at th...        1
# 0   \r\n                    #digitalnomad #colorfu...        2
# 1   \r\n                    I'm ready! 🏂\n\n#fun ...        4
# 2   \r\n                    #sunset #dusk #dawn #e...        0
# 3   \r\n                    #photo #photography #p...        1
# 4   \r\n                    #creativesma #nature #...        2
# 5   \r\n                    #photography #photogra...        4
# 6   \r\n                    봉은사 홍매화  with Leica SL...        0
# 7   \r\n                    Selamat pagi kyai dan ...        0
# 8   \r\n                    #emo#scene#goth#black#...        1
# 9   \r\n                    #photography #photowit...        0
# 10  \r\n                    Another side of the ro...        2
# 11  \r\n                    The girls are about ha...        0
# 12  \r\n                    #sunrise #sunset #sun ...        2
# 13  \r\n                    #GullLyfe Gorgeous day...        0
# 14  \r\n                    Deer Crossing the stre...        0
#
#              filters                                           hashtags  \
# 0      Filter Normal   #spring #alicante #nature #flower #paradise #...
# 1   Filter Clarendon   #followme #followforfollow #nature #newsocial...
# 2      Filter Normal   #nature #outside #photography #nofilter #niko...
# 3      Filter Normal   #감성스냅 #이미지메이킹잉글리시q #일상을담은 #스냅 #영어발음의신 #서울 #카페...
# 4      Filter Normal   #natgeo #mtmanolimit #travelling #transtv #tv...
# 5   Filter Clarendon   #red #trippy #guyswithpercings #male #tatto #...
# 6      Filter Normal   #naturelovers #lovefl #naturephotography #for...
# 7      Filter Normal   #seattle #lifeisgreat #washingtonstate #smell...
# 8   Filter Clarendon   #weightloss #healthy #swfl #cardio #estero #f...
# 9      Filter Ludwig   #red #pink #clouds #instasky #morning #sunset...
# 10    Filter Mayfair   #food #oregon #oregoncoast #adventure #earth ...
# 11     Filter Normal     #deer #afternoon #deercrossing #nature #spring
# 12     Filter Normal   #fleur #bloom #gettycentre #flower #fiori #fl...
# 13  Filter Clarendon   #nomakeup #tattoo #huskiesofinstagram #photog...
# 14     Filter Normal   #sunset #likeforlike #ootd #seaporn #sea #swi...
# 0        Filter Hefe   #roadtrip #pinapple #vacation #summer #digita...
# 1     Filter Mayfair   #sports #italia #cool #goodmorningpost #mount...
# 2       Filter Lo-fi   #colourful #brilliant #horizon #sky #art #dra...
# 3      Filter Normal   #flower #alicante #nature #españa #paradise #...
# 4   Filter Clarendon   #nature #growth #relax #newsocialmediaagencyi...
# 5      Filter Normal   #picture #nikond3300 #nature #outside #photog...
# 6      Filter Normal   #영어발음의신 #곤충 #카페 #everyday #insects #한국 #꽃 #sn...
# 7      Filter Normal   #regrann #tvprogramme #transmedia #transtv #b...
# 8   Filter Clarendon   #darkmagic #tatto #scene #hippy #metal #red #...
# 9      Filter Normal   #nature #photowithmyphone #photography #flori...
# 10     Filter Normal   #treehugger #lifeisgreat #nature #photoadaych...
# 11  Filter Clarendon   #outside #nogym #fitfam #weightloss #personal...
# 12     Filter Ludwig   #instasky #warm #horizon #tflers #red #silhou...
# 13    Filter Mayfair   #live #foodies #chef #foodporn #cooking #eart...
# 14     Filter Normal     #deercrossing #deer #spring #nature #afternoon
#
#                                                 image  \
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
# 0   https://scontent.cdninstagram.com/t51.2885-15/...
# 1   https://scontent.cdninstagram.com/t51.2885-15/...
# 2   https://scontent.cdninstagram.com/t51.2885-15/...
# 3   https://scontent.cdninstagram.com/t51.2885-15/...
# 4   https://scontent.cdninstagram.com/t51.2885-15/...
# 5   https://scontent.cdninstagram.com/t51.2885-15/...
# 6   https://scontent.cdninstagram.com/t51.2885-15/...
# 7   https://scontent.cdninstagram.com/t51.2885-15/...
# 8   https://scontent.cdninstagram.com/t51.2885-15/...
# 9   https://scontent.cdninstagram.com/t51.2885-15/...
# 10  https://scontent.cdninstagram.com/t51.2885-15/...
# 11  https://scontent.cdninstagram.com/t51.2885-15/...
# 12  https://scontent.cdninstagram.com/t51.2885-15/...
# 13  https://scontent.cdninstagram.com/t51.2885-15/...
# 14  https://scontent.cdninstagram.com/t51.2885-15/...
#
#                                                   key likes  photo_id  \
# 0                                                 ...    35       1.0
# 1                                                 ...    11       2.0
# 2                                                 ...    22       3.0
# 3                                                 ...    21       4.0
# 4                                                 ...   150       5.0
# 5                                                 ...    37       6.0
# 6                                                 ...    13       7.0
# 7                                                 ...    19       8.0
# 8                                                 ...    45       9.0
# 9                                                 ...    71      10.0
# 10                                                ...    37      11.0
# 11                                                ...    14      12.0
# 12                                                ...    19      13.0
# 13                                                ...    26      14.0
# 14                                                ...    41      15.0
# 0                                                 ...    32      16.0
# 1                                                 ...    80      17.0
# 2                                                 ...    22      18.0
# 3                                                 ...    35      19.0
# 4                                                 ...    11      20.0
# 5                                                 ...    22      21.0
# 6                                                 ...    21      22.0
# 7                                                 ...   150      23.0
# 8                                                 ...    37      24.0
# 9                                                 ...    13      25.0
# 10                                                ...    19      26.0
# 11                                                ...    45      27.0
# 12                                                ...    71      28.0
# 13                                                ...    37      29.0
# 14                                                ...    14      30.0
#
#                    post_time               scrape_time     tag          time  \
# 0   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:07:58 2017  nature  23 hours ago
# 1   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:07:58 2017  nature  23 hours ago
# 2   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:07:59 2017  nature  23 hours ago
# 3   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:00 2017  nature  23 hours ago
# 4   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:00 2017  nature  23 hours ago
# 5   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:00 2017  nature  23 hours ago
# 6   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:01 2017  nature     1 day ago
# 7   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:01 2017  nature  23 hours ago
# 8   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:01 2017  nature  23 hours ago
# 9   Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:01 2017  nature  23 hours ago
# 10  Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:01 2017  nature  23 hours ago
# 11  Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:03 2017  nature  23 hours ago
# 12  Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:03 2017  nature  23 hours ago
# 13  Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:03 2017  nature  23 hours ago
# 14  Thu Mar 16 21:12:26 2017  Fri Mar 17 21:08:03 2017  nature  23 hours ago
# 0   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:05 2017  nature  23 hours ago
# 1   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:05 2017  nature  23 hours ago
# 2   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:05 2017  nature  23 hours ago
# 3   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:05 2017  nature  23 hours ago
# 4   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:05 2017  nature  23 hours ago
# 5   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:06 2017  nature  23 hours ago
# 6   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:07 2017  nature  23 hours ago
# 7   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:07 2017  nature  23 hours ago
# 8   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:07 2017  nature  23 hours ago
# 9   Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:07 2017  nature     1 day ago
# 10  Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:07 2017  nature  23 hours ago
# 11  Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:08 2017  nature  23 hours ago
# 12  Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:08 2017  nature  23 hours ago
# 13  Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:08 2017  nature  23 hours ago
# 14  Thu Mar 16 21:12:28 2017  Fri Mar 17 21:08:08 2017  nature  23 hours ago
#
#                               user
# 0                    @hrnndezphoto
# 1                     @creativesma
# 2     @stephaniezamudiophotography
# 3                        @leica_sl
# 4   @sahabatmarshallsastra_lampung
# 5                 @daddy_reaper666
# 6                 @nb_photosoflife
# 7                @shouts_n_gigglez
# 8            @johnathanblevinsfitt
# 9                       @schiunyix
# 10                  @bluwillowgurl
# 11                     @natoriousw
# 12                    @meinhard.mm
# 13            @twistedhuskysisters
# 14                    @irene_life8
# 0                     @jcaronphoto
# 1                       @kravpanda
# 2                      @mantanomay
# 3                    @hrnndezphoto
# 4                     @creativesma
# 5     @stephaniezamudiophotography
# 6                        @leica_sl
# 7   @sahabatmarshallsastra_lampung
# 8                 @daddy_reaper666
# 9                 @nb_photosoflife
# 10               @shouts_n_gigglez
# 11           @johnathanblevinsfitt
# 12                      @schiunyix
# 13                  @bluwillowgurl
# 14                     @natoriousw

# %% [markdown]
# And finally write that file to a csv!

# %%
final.to_csv('Insta.csv', encoding = 'utf-8')
