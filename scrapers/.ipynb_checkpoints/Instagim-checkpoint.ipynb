# %% [markdown]
# First, we want to load packages and create an empty data frame to be filled. Additionally, define a starter key to collect more keys

# %%
import requests
import json
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import time 
import datetime
final = pd.DataFrame(columns = ['caption','comments','filters','hashtags','image','index','likes','time','user']) 
#chance this key will have to be changed over time - atm it's just to start collecting other keys
key = 'AQDt5LYE7lbm7Rb2P-ox-rkpSdXXT19HsvYz4Ncf_k2qcjJ3S2crfI9m-jipFD0SOtWBTAIEKkU1AozNIhN52-wfgMbUTr1biNafa9RGWnQpF6izIF8GIiNf1Dvdl_IbnR4'
counter = 0

# %% [markdown]
# Only run the code below if you're looking to get more keys. The number of keys you get will depend on the range

# %%
#collect keys
start = time.time()
keys = []
for i in range(0,1000):
    response = requests.post("http://www.instagim.com/ajax/",
        data='get_photos=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%' + key + '%count%3D15%26access_token%3D&next_url=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D%7Bnext_key%7D%26count%3D15%26access_token%3D',
        headers={
            "Accept": "application/json, text/javascript, */*; q=0.01",
            "Accept-Encoding": "gzip, deflate",
            "Accept-Language": "en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4",
            "Connection": "keep-alive",
            "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
            "Origin": "http://www.instagim.com",
            "Referer": "http://www.instagim.com/tag/nature",
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
            "X-Requested-With": "XMLHttpRequest"
        },
        cookies={
            "_ga": "GA1.2.821769385.1489495570",
            "_gat": "1"
        },
    )
    data = json.loads(response.text)
    key = data['key'].encode('utf-8')
    keys.append(key)
    time.sleep(1)
    
print 'Time elapsed: ', time.time() - start
# Out:
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# Time elapsed:  2194.0166049

# %% [markdown]
# Simply writing the keys to a csv file while the photos "mature" like fine wine.

# %%
keys_df = pd.DataFrame(keys)
print keys_df.head()
keys_df.to_csv('keys'+ str(time.strftime("%c") + '.csv'))
# Out:
#                                                    0
# 0  AQCz6KH-Tg8kAgZYf9gVHGQciBAyxvoJmwc8Jo3MoLQzPx...
# 1  AQDUMjB3h23-juJ8CZVdPHiLTCblMGKrnC8c_SfLM8pLzW...
# 2  AQA1y8pO3ykBF_Zj5IQWb8mhLjp3_M9u4FXMu8IPhB47Mp...
# 3  AQDdUo6qDalPISDQMJQbPzzvM17ymsPgdk4Zrfc3LtgTgh...
# 4  AQCJH7GFJGNuTe0FbDOhq8gJqGBDQsXorE7lVsYEqEn9sO...

# %% [markdown]
# Now, we want to use yesterdays keys to actually get the data we want.

# %%
key = pd.read_csv('keys_Wed_Mar_15_17_02_00_2017.csv')
key = key['0'].tolist()
key = key[30]
key
# Out:
# 'AQBzHSpvMHOxi7S467Jtd2fJoAiv1jnRR6D-WhkDVngPI7ITocRqx0SO0Wsb9VNYdXd92U6ul7saqP4u_AhbWTSohi-fwANBFOpC-0cZ3k2ClvhSkm_7tuo_yr8oeu7e_Vk'

# %%
#for key in keys:
    


response = requests.post("http://www.instagim.com/ajax/",
    data='get_photos=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D' + key + '%26count%3D15%26access_token%3D&next_url=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D%7Bnext_key%7D%26count%3D15%26access_token%3D',
    headers={
        "Accept": "application/json, text/javascript, */*; q=0.01",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4",
        "Connection": "keep-alive",
        "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "http://www.instagim.com",
        "Referer": "http://www.instagim.com/tag/nature",
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
        "X-Requested-With": "XMLHttpRequest"
    },
    cookies={
        "_ga": "GA1.2.821769385.1489495570",
        "_gat": "1"
    },
)

data = json.loads(response.text)

text = BeautifulSoup(data['html'], 'html.parser')

events = text.find_all('div', {'class': "box-photo"})


result = [] 
for event in events:
    counter += 1
    d = {} # each event is its own dictionary so initialize it inside the loop
    try: #use try statement so code doesn't break if names are wrong
             #remember to change this to a counter
            index = counter
            im = [x['src'] for x in event.find('div', {'class': 'photo'}).a][0]
            urllib.urlretrieve(im, str(counter) + ".jpg")
            time = event.find('div', {'class': "upload-time"}).get_text()
            user = event.find('div', {'class': "username"}).a.get_text()
            capt = event.find('div', {'class': "photo-description"}).get_text()
            hashtags = event.find('div', {'class': "photo-tags"}).get_text()
            filters = event.find('div', {'class': "filter-text"}).get_text()
            likes = event.find('span', {'class': "icon-thumbs-up-alt"}).get_text()
            comments = event.find('span', {'class': "icon-chat"}).get_text()
    except: 
            index = ""
            im = ""
            timeTags = ""
            userTags = ""
            descTags = ""
            hashTags = ""
            filterTags = ""
            likes = ""
            comments = ""
    finally:  
            d['index'] = index
            d['image'] = im
            d['time'] = time
            d['user'] = user             
            d['caption'] = capt
            d['hashtags'] = hashtags
            d['filters'] = filters
            d['likes'] = likes
            d['comments'] = comments
            result.append(d) # each event is own dictionary, at the end of each loop we append it to the list, we get list of dic

final = final.append(pd.DataFrame(result))

# %%
final
# Out:
#                                               caption comments  \
# 0   \r\n                    After the rain, comes ...        1
# 1   \r\n                    First of 2017! \n#natu...        0
# 2   \r\n                    #magnolia #magnoliatre...        0
# 3   \r\n                    Paradise... 🏔☀️\n#nat...        0
# 4   \r\n                    😌🙄🙋#nature #sky #su...        0
# 5   \r\n                    Look at the amazing ab...        0
# 6   \r\n                    Go home! 🌄☝💨\n#brasi...        0
# 7   \r\n                    Into the wild - #natur...        0
# 8   \r\n                    🍃🌹🌼 learning photog...        0
# 9   \r\n                    Linia// ✖️✖️ #fjord #f...        0
# 10  \r\n                    #nature #scenic #water...        0
# 11  \r\n                    #hawaii #holidays #isl...        0
# 12  \r\n                    step by step\r\n      ...        1
# 13  \r\n                    Platja de Fenals. Cost...        0
# 14  \r\n                    brush strokes\n#sun7et...        0
# 0   \r\n                    ●|| Journée ensoleillé...        0
# 1   \r\n                    Spring is coming🎉 #fl...        0
# 2   \r\n                    #flores #flowers #inst...        0
# 3   \r\n                    Londyn, Park Holenders...        0
# 4   \r\n                    #petsofinstagram #she ...        0
# 5   \r\n                    Hello Spring 🌸 #pictu...        0
# 6   \r\n                    Скорее бы лето 😩\n@su...        0
# 7   \r\n                    #birdsoninstagram #bir...        0
# 8   \r\n                    #spring #time #canon #...        0
# 9   \r\n                    Good boy\r\n          ...        1
# 10  \r\n                    💙💙💙#tagsapp #nature...        0
# 11  \r\n                    🌿 #nature #toptags @t...        0
# 12  \r\n                    📷 by ingridrolke \n#s...        0
# 13  \r\n                    #nature #relax#time#wo...        0
# 14  \r\n                    Hace un timpo lei este...        0
# ..                                                ...      ...
# 0   \r\n                    My model today.\n\n#sh...        2
# 1   \r\n                    Jesus the King🕇\n\nww...        3
# 2   \r\n                    Frühlingstage...Die Gl...        1
# 3   \r\n                    Sky was putting on a b...        0
# 4   \r\n                    Swimming, swimming in ...        2
# 5   \r\n                    Stare zdjęcie #lategra...        0
# 6   \r\n                    #panoramic #panorami #...        0
# 7   \r\n                    Please don't touch the...        1
# 8   \r\n                    A bit of rain...and th...        5
# 9   \r\n                    Psalm 119:105\n#path #...        1
# 10  \r\n                    ••DroppinKeepsYouWarm^...        2
# 11  \r\n                    #sky #sunbreak #dawn #...        1
# 12  \r\n                    #analogphotography #na...        0
# 13  \r\n                    Anche quest'anno siete...        0
# 14  \r\n                    Il cielo farà il suo d...        4
# 0   \r\n                    My model today.\n\n#sh...        2
# 1   \r\n                    Jesus the King🕇\n\nww...        3
# 2   \r\n                    Frühlingstage...Die Gl...        1
# 3   \r\n                    Sky was putting on a b...        0
# 4   \r\n                    Swimming, swimming in ...        2
# 5   \r\n                    Stare zdjęcie #lategra...        0
# 6   \r\n                    #panoramic #panorami #...        0
# 7   \r\n                    Please don't touch the...        1
# 8   \r\n                    A bit of rain...and th...        5
# 9   \r\n                    Psalm 119:105\n#path #...        1
# 10  \r\n                    ••DroppinKeepsYouWarm^...        2
# 11  \r\n                    #sky #sunbreak #dawn #...        1
# 12  \r\n                    #analogphotography #na...        0
# 13  \r\n                    Anche quest'anno siete...        0
# 14  \r\n                    Il cielo farà il suo d...        4
#
#            filters                                           hashtags  \
# 0    Filter Normal   #happy #blue #beautiful #byblos #seaside #wav...
# 1      Filter Lark   #jeans #livelife #beautiful #outdoorlife #pho...
# 2    Filter Normal   #magnoliatree #almostspring #spring #boulogne...
# 3    Filter Normal   #life #landscape #beautiful #happiness #natur...
# 4    Filter Normal   #dusk #photooftheday #beautiful #skylovers #n...
# 5    Filter Normal   #newislingtonfreeschool #primaryschool #artsw...
# 6     Filter Amaro                    #nature #brasil #street #gohome
# 7    Filter Ludwig            #wild #charging #energy #temple #nature
# 8    Filter Normal   #learning #green #lens #nature #photography #...
# 9    Filter Normal   #adventure #travel #pic #space #water #norge ...
# 10   Filter Normal                        #waterfalls #scenic #nature
# 11   Filter Normal   #hawaiilife #amazingtrip #holidays #traveladd...
# 12   Filter Normal   #vscobrasil #beautiful #vsco #vscocam #vscobr...
# 13     Filter Lark   #travelphoto #pic #nature #naturaleza_catalun...
# 14   Filter Normal   #exploretocreate #dusk #featured #beautiful #...
# 0    Filter Normal   #girl #igers #followme #selfie #instalike #sm...
# 1    Filter Normal   #goodweather #followme #f4f #spring #nature #...
# 2      Filter Juno   #flower #loveflowers #instaflower #nature #fl...
# 3    Filter Normal   #park #bird #london #britain #green #natureph...
# 4     Filter Lo-fi   #beauty #image #she #together #picsart #natur...
# 5    Filter Normal   #pink #instadaily #spring #nature #beautiful ...
# 6    Filter Normal   #trip #blue #beauty #деревья #day #dream #nat...
# 7     Filter Lo-fi   #pictureoftheday #bird #insta #love #naturelo...
# 8    Filter Normal   #springfeeling #capture #green #spring #persp...
# 9    Filter Normal   #wanderlust #globe #earth #adventure #travelt...
# 10   Filter Normal   #lookup #instagood #skyporn #clouds #cloudpor...
# 11   Filter Normal   #ig_worldclub #mothernature #ig_nature #cloud...
# 12   Filter Normal   #schilf #niedersachsen #sande #naturephotogra...
# 13   Filter Normal                    #wonderful #nature #time #relax
# 14   Filter Normal                                            #nature
# ..             ...                                                ...
# 0    Filter Normal   #city #love #berlin #photography #nature #mal...
# 1    Filter Normal   #instalike #naturelovers #green #tb #tree #su...
# 2     Filter Amaro   #frühling #mylife #wald #весна #vordertür #цв...
# 3     Filter Amaro   #pretty #nature #melbourne #sunrise #burnleys...
# 4   Filter Gingham   #bohemian #waves #backpacker #boho #ocean #hi...
# 5    Filter Normal   #trekking #zyjebyniesiedziecwmiejscu #naturel...
# 6    Filter Normal   #italia #naturelovers #photographers #sunset ...
# 7    Filter Normal   #mama #floral #1920s #garden #photooftheday #...
# 8    Filter Normal   #naturephotography #animals #insect #wanderlu...
# 1    7 seconds ago    @oppenauerova.eliska
# 2    5 seconds ago              @nynecosta
# 3    5 seconds ago          @lukasz.luciuk
# 4    3 seconds ago         @helenbentancor
# 5    3 seconds ago        @lucie_bourillon
# 6    3 minutes ago            @_cosmostars
# 7    3 seconds ago             @turturilla
# 8    5 seconds ago    @iridescent.solitude
# 9   15 seconds ago           @vicente_guti
# 10   6 minutes ago    @victoria_sudyankova
# 11   7 seconds ago      @kayllon_fernandes
# 12   5 seconds ago             @mannirolke
# 13   6 seconds ago            @zara_yan_95
# 14  47 seconds ago         @nathaliapertuz
# ..             ...                     ...
# 0     20 hours ago            @cindysittig
# 1     20 hours ago    @charbelfersan_photo
# 2     20 hours ago           @iiiraaaaaaai
# 3     20 hours ago    @its_pronounced_nick
# 4     20 hours ago           @bohocrystals
# 5     20 hours ago         @english_at_tea
# 6     20 hours ago           @specchio1974
# 7     20 hours ago          @hawaikis2meke
# 8     20 hours ago  @tara_australia_norway
# 9     20 hours ago     @abigailgracephotog
# 10    20 hours ago       @droppin.clothing
# 11    20 hours ago                @amenahk
# 12    20 hours ago           @borisdammler
# 13    20 hours ago                @lolladb
# 14    20 hours ago          @giuseraine_97
# 0     20 hours ago            @cindysittig
# 1     20 hours ago    @charbelfersan_photo
# 2     20 hours ago           @iiiraaaaaaai
# 3     20 hours ago    @its_pronounced_nick
# 4     20 hours ago           @bohocrystals
# 5     20 hours ago         @english_at_tea
# 6     20 hours ago           @specchio1974
# 7     20 hours ago          @hawaikis2meke
# 8     20 hours ago  @tara_australia_norway
# 9     20 hours ago     @abigailgracephotog
# 10    20 hours ago       @droppin.clothing
# 11    20 hours ago                @amenahk
# 12    20 hours ago           @borisdammler
# 13    20 hours ago                @lolladb
# 14    20 hours ago          @giuseraine_97
#
# [135 rows x 9 columns]

# %%
final.to_csv('Insta.csv', sep='\t', encoding = 'utf-8')

# %%
# Out:
# 1489611419.116635

# %%
response = requests.post("http://www.instagim.com/ajax/",
    data='get_photos=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%AQAVBM52o9yVXxV7kn6LW3z9yZ-XYQvbCsMrJZHGuLh-1QU-dw_68EilFIO6fcppZCmbPa7KcgK8QUNmesOZ0LXF9tClskGrvAVG1uYOkMRop8beQAJZdYFs-X56Z6MsBdM%26count%3D15%26access_token%3D&next_url=https%3A%2F%2Fapi.instagram.com%2Fv1%2Ftags%2Fnature%2Fmedia%2Frecent%3Fmax_tag_id%3D%7Bnext_key%7D%26count%3D15%26access_token%3D',
    headers={
        "Accept": "application/json, text/javascript, */*; q=0.01",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4",
        "Connection": "keep-alive",
        "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "http://www.instagim.com",
        "Referer": "http://www.instagim.com/tag/nature",
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
        "X-Requested-With": "XMLHttpRequest"
    },
    cookies={
        "_ga": "GA1.2.821769385.1489495570",
        "_gat": "1"
    },
)

print response.text
# Out:
# {"key":"AQDuQODfX4ZU4CccgBlSDum5QkexBb_3fobmQybF8CztTq8QlEFPYfDYrhyYtyo8E_2jBtViyIpp9b_z5vTv1R5DZCg9pElce1N79xrQKcP8n_bIryigDkStQl5YmSxRKHY","html":"<div class=\"box-photo\">\r\n            <div class=\"photo\"><a href=\"\/photo\/tobbymarshall815\/1471065299876768401_314708848\"><img src=\"https:\/\/scontent.cdninstagram.com\/t51.2885-15\/sh0.08\/e35\/p640x640\/17333188_270926226681484_5427424831924600832_n.jpg\" alt=\"tobbymarshall815\"><\/a>\r\n            <\/div>
# %%
final = final.append(pd.DataFrame(result))

# %%
data = json.loads(response.text)
text = BeautifulSoup(data['html'], 'html.parser')
events = text.find_all('div', {'class': "box-photo"})
result = [] 
for event in events:
    d = {} # each event is its own dictionary so initialize it inside the loop
    try: #use try statement so code doesn't break if names are wrong
            im = [x['src'] for x in text.find('div', {'class': 'photo'}).a][0]
            time = event.find('div', {'class': "upload-time"}).get_text()
            user = event.find('div', {'class': "username"}).a.get_text()
            capt = event.find('div', {'class': "photo-description"}).get_text()
            hashtags = event.find('div', {'class': "photo-tags"}).get_text()
            filters = event.find('div', {'class': "filter-text"}).get_text()
            likes = event.find('span', {'class': "icon-thumbs-up-alt"}).get_text()
            comments = event.find('span', {'class': "icon-chat"}).get_text()
    except: 
            im = ""
            timeTags = ""
            userTags = ""
            descTags = ""
            hashTags = ""
            filterTags = ""
            likes = ""
            comments = ""
    finally:  
            d['image'] = im
            d['time'] = time
            d['user'] = user             
            d['caption'] = capt
            d['hashtags'] = hashtags
            d['filters'] = filters
            d['likes'] = likes
            d['comments'] = comments
            result.append(d) # each event is own dictionary, at the end of each loop we append it to the list, we get list of dic

# %%
y = pd.DataFrame()
pd.DataFrame(result)
# Out:
#                                               caption comments  \
# 0   \r\n                    Simplemente naturaleza...        0
# 1   \r\n                    The kids made binocula...        1
# 2   \r\n                    Back to Sorrento a yea...        0
# 3   \r\n                    Swimming in the Blue L...        0
# 4   \r\n                    #kyivlove #kievgo #pho...        0
# 5   \r\n                    Red-eyed green tree fr...        0
# 6   \r\n                    Buenas noches mundo 🌍...        0
# 7   \r\n                    🌼🌼\n#nature #flower ...        0
# 8   \r\n                    😻 😻  #heechul ☆ #민경훈...        0
# 9   \r\n                    In my natural habitat ...        0
# 10  \r\n                    Favorite part about th...        0
# 11  \r\n                    #HalfmoonBay #Californ...        0
# 12  \r\n                    FRIEND\n-\n-\n-\n#vsco...        0
# 13  \r\n                    Collection 3 look 📷 @...        0
# 14  \r\n                    Go go go... Biar ngak ...        0
#
#              filters                                           hashtags  \
# 0      Filter Normal   #instachile #lagoon #sky #summer #colors #nat...
# 1      Filter Normal   #nests #kidkits #learning #explore #ispy #out...
# 2     Filter Mayfair   #naturelover #beach #sorrento #australiagram ...
# 3      Filter Normal   #dream #swim #winter #europe #traveler #explo...
# 4      Filter Normal   #kyivlove #photographer #photoart #photograph...
# 5      Filter Normal   #wildlifephotography #treefrog #costarica🇨🇷...
# 6      Filter Normal   #beautiful #positivethinking #heart #model #o...
# 7      Filter Normal              #nature #white #urban #flower #garden
# 8      Filter Normal   #아는형님 #강호동 #taeyeon_ss #kpop #태연아사랑해 #이수근 #사랑...
# 9      Filter Normal   #photography #candid #flowerchild #hippie #na...
# 10  Filter Clarendon   #beautiful #nyc #winter #peaceful #instagood ...
# 11     Filter Normal   #photooftheday #beautiful #bayarea #focus #la...
# 12     Filter Normal   #hallazgosemanal #photographer #friend #vscoc...
# 13     Filter Normal   #fashion #illest #nokwal #streetfashion #outf...
# 14     Filter Normal                       #nature #sea #explore #speed
#
#                                                 image likes           time  \
# 0   https://scontent.cdninstagram.com/t51.2885-15/...     0  4 seconds ago
# 1   https://scontent.cdninstagram.com/t51.2885-15/...     8     1 hour ago
# 2   https://scontent.cdninstagram.com/t51.2885-15/...     0  7 seconds ago
# 3   https://scontent.cdninstagram.com/t51.2885-15/...     0  6 seconds ago
# 4   https://scontent.cdninstagram.com/t51.2885-15/...     0  6 seconds ago
# 5   https://scontent.cdninstagram.com/t51.2885-15/...     0  5 seconds ago
# 6   https://scontent.cdninstagram.com/t51.2885-15/...     0  5 seconds ago
# 7   https://scontent.cdninstagram.com/t51.2885-15/...     0  6 seconds ago
# 8   https://scontent.cdninstagram.com/t51.2885-15/...     0   1 minute ago
# 9   https://scontent.cdninstagram.com/t51.2885-15/...     0  8 seconds ago
# 10  https://scontent.cdninstagram.com/t51.2885-15/...     0  7 seconds ago
# 11  https://scontent.cdninstagram.com/t51.2885-15/...     0  7 seconds ago
# 12  https://scontent.cdninstagram.com/t51.2885-15/...     0  8 seconds ago
# 13  https://scontent.cdninstagram.com/t51.2885-15/...     0  8 seconds ago
# 14  https://scontent.cdninstagram.com/t51.2885-15/...     0  9 seconds ago
#
#                     user
# 0              @hjriesco
# 1              @kid.kits
# 2         @elizawangziyi
# 3          @groovytuna13
# 4   @kaliuzhnyi.theodore
# 5       @carolinewoodall
# 6             @biggsmart
# 7         @evelynsandoli
# 8     @diamondkimtaeyeon
# 9         @lizzie_lister
# 10     @jenniferstpierre
# 11       @casadeorellana
# 12               @avgeos
# 13               @nokwal
# 14              @zy_izzy

# %%
data['key'].encode('utf-8')
# Out:
# 'AQDt5LYE7lbm7Rb2P-ox-rkpSdXXT19HsvYz4Ncf_k2qcjJ3S2crfI9m-jipFD0SOtWBTAIEKkU1AozNIhN52-wfgMbUTr1biNafa9RGWnQpF6izIF8GIiNf1Dvdl_IbnR4'

# %%
urllib.urlretrieve(im, str(1) + ".jpg")
# Out:
# ('1.jpg', <httplib.HTTPMessage instance at 0x112b1ab90>)

# %%
im = [x['src'] for x in text.find('div', {'class': 'photo'}).a][0]
im
# Out:
# u'https://scontent.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17126484_100573000480526_3992055557694423040_n.jpg'

# %%
#old tests n shit



timeTags = text.find_all('div', {'class': "upload-time"})
userTags = text.find_all('div', {'class': "username"})
descTags = text.find_all('div', {'class': "photo-description"})
hashTags = text.find_all('div', {'class': "photo-tags"})
filterTags = text.find_all('div', {'class': "filter-text"})
likes = text.find_all('span', {'class': "icon-thumbs-up-alt"})
comments = text.find_all('span', {'class': "icon-chat"})


timeString = [tag.get_text() for tag in timeTags]
userString = [tag.get_text() for tag in userTags]
descString = [tag.get_text() for tag in descTags]
hashString = [tag.get_text() for tag in hashTags]
filterString = [tag.get_text() for tag in filterTags]
likeString = [tag.get_text() for tag in likes]
commentString = [tag.get_text() for tag in comments]

print len(text.find_all('div', {'class': "box-photo"}))
#print im
#print timeString
#print userString
#print descString
#print hashString
#print filterString
#print likeString
